# %%
#hello!!

# this is my initial implementation of Word2Vec 
import numpy as np
import pandas as pd
from sklearn.utils import shuffle

df = pd.read_csv("train_data.csv")

df
# Out:
#                                                     text  label
# 0      Here are Thursday's biggest analyst calls: App...      0
# 1      Buy Las Vegas Sands as travel to Singapore bui...      0
# 2      Piper Sandler downgrades DocuSign to sell, cit...      0
# 3      Analysts react to Tesla's latest earnings, bre...      0
# 4      Netflix and its peers are set for a ‘return to...      0
# ...                                                  ...    ...
# 16985  KfW credit line for Uniper could be raised to ...      3
# 16986  KfW credit line for Uniper could be raised to ...      3
# 16987  Russian  https://t.co/R0iPhyo5p7 sells 1 bln r...      3
# 16988  Global ESG bond issuance posts H1 dip as supra...      3
# 16989  Brazil's Petrobras says it signed a $1.25 bill...      3
#
# [16990 rows x 2 columns]

# %%
df = shuffle(df)
df
# Out:
#                                                     text  label
# 10487  Europe’s shrinking pork output could soon make...     14
# 13389  Liz Truss and Rishi Sunak have sharply diverge...     16
# 1734   Palantir Named a Leader in AI/ML Platforms by ...      2
# 10887  “We just had a 9.1% CPI print,” @SimplifyETFs ...     14
# 5191   $BK - The Bank of New York Mellon Corporation ...      5
# ...                                                  ...    ...
# 10972   JUN CPI M/M: +1.3% V 1.1%E;  Y/Y:  +9.1% V 8.8%E     14
# 3351   Oakmark Select Fund: Q2 2022 Commentary.  http...      2
# 9607   Eye Health America Announces Newest Acquisitio...     13
# 4950   $TFC - Truist Financial Q2 2022 Earnings Previ...      5
# 2314   General Electric just unveiled the names of it...      2
#
# [16990 rows x 2 columns]

# %%
text_column = "text"
label_column = "label"

# %%
#WORD 2 VEC
from nltk.tokenize import TweetTokenizer
tokenizer = TweetTokenizer()
df["tokens"] = df[text_column].apply(lambda tweet: tokenizer.tokenize(tweet.lower()))
sentences = df["tokens"].tolist()
sentences #this tokenizes them and does a litttle bit of preprocessing, used the one specifically for tweets!

# Word2Vec needs lists of words like this!!
# Out:
# [['europe',
#   '’',
#   's',
#   'shrinking',
#   'pork',
#   'output',
#   'could',
#   'soon',
#   'make',
#   'bacon',
#   'more',
#   'expensive',
#   'https://t.co/cjipjv6bas'],
#  ['liz',
#   'truss',
#   'and',
#   'rishi',
#   'sunak',
#   'have',
#   'sharply',
#   'divergent',
#   'views',
#   'on',
#   'how',
#   'to',
#   'handle',
#   "britain's",
#   'economy',
#   'and',
#   'public',
#   'finances',
#   'https://t.co/xzakpaddmz'],
#  ['palantir',
#   'named',
#   'a',
#   'leader',
#   'in',
#   'ai',
#   '/',
#   'ml',
#   'platforms',
#   'by',
#   'independent',
#   'research',
#   'firm',
#   'https://t.co/y80plsy5jf',
#   'https://t.co/e7fty21wva'],
#  ['“',
#   'we',
#   'just',
#   'had',
#   'a',
#   '9.1',
#   '%',
#   'cpi',
#   'print',
#   ',',
#   '”',
#   '@simplifyetfs',
#   'ceo',
#   'paul',
#   'kim',
#   'says',
#   '.',
#   '“',
#   'inflation',
#   'is',
#   'here',
#   'to',
#   'stay',
#   'for',
#   'a',
#   'bit',
#   '…',
#   'maybe',
#   'a',
#   'couple',
#   'years',
#   'even',
#   '.',
#   '”',
#   'full',
#   'comments',
#   ':',
#   'https://t.co/vc9t1cv6dh'],
#  ['$',
#   'bk',
#   '-',
#   'the',
#   'bank',
#   'of',
#   'new',
#   'york',
#   'mellon',
#   'corporation',
#   '2022',
#   'q2',
#   '-',
#   'results',
#   '-',
#   'earnings',
#   'call',
#   'presentation',
#   '.',
#   'https://t.co/tbdoleou1c',
#   '#investing',
#   '#stocks',
#   '#stockmarket'],
#  ['vanguard',
#   'renewables',
#   'announces',
#   'acquisition',
#   'by',
#   'blackrock',
#   'real',
#   'assets',
#   'https://t.co/4nxydgizoe',
#   'https://t.co/wbfmj2qaby'],
#  ['former',
#   'gap',
#   'ceo',
#   ':',
#   'i',
#   "can't",
#   'remember',
#   'seeing',
#   'this',
#   'much',
#   'discounting',
#   'in',
#   'retail',
#   'https://t.co/qaooake44y',
#   'by',
#   '@briansozzi',
#   'https://t.co/2khy9e4z8u'],
#  ['a',
#   'new',
#   'plant',
#   'in',
#   'japan',
#   'is',
#   'helping',
#   'tackle',
#   'one',
#   'of',
#   'the',
#   'biggest',
#   'scourges',
#   'of',
#   'global',
#   'warming',
#   ':',
#   'cow',
#   'poop',
#   'https://t.co/d9t60mf91v'],
#  ['$',
#   'mat',
#   '-',
#   'mattel',
#   'q2',
#   '2022',
#   'earnings',
#   'preview',
#   'https://t.co/xmfdkttpo1'],
#  ['$',
#   'prgo',
#   'triggers',
#   'early',
#   'with',
#   'the',
#   'news',
#   ',',
#   'been',
#   'a',
#   'popular',
#   'bull',
#   'r',
#   '/',
#   'r',
#   'name'],
#  ['$',
#   'gm',
#   '$',
#   'f',
#   '$',
#   'hmc',
#   '-',
#   'gm',
#   ',',
#   'toyota',
#   ',',
#   'ford',
#   'among',
#   'automakers',
#   'recalling',
#   'thousands',
#   'of',
#   'vehicles',
#   'https://t.co/lptlwzpt8l'],
#  ['#bankofamerica',
#   'posts',
#   'solid',
#   'quarter',
#   ';',
#   'us',
#   'consumer',
#   'resilient',
#   ',',
#   'but',
#   'concerns',
#   'linger',
#   'as',
#   'we',
#   'enter',
#   '2h',
#   '$',
#   'bac',
#   '$',
#   'jpm',
#   '$',
#   'c',
#   'https://t.co/n5mdq8pq1d',
#   '#bankstocks',
#   '#consumer',
#   '#banking',
#   '#bank',
#   '#earnings',
#   '#interestrates',
#   '#inflation',
#   '#recession',
#   '#economy',
#   '#stockmarket'],
#  ['us',
#   'inflation',
#   'roared',
#   'again',
#   'to',
#   'a',
#   'fresh',
#   'four-decade',
#   'high',
#   'last',
#   'month',
#   ',',
#   'likely',
#   'strengthening',
#   'the',
#   'federal',
#   'reserve',
#   '’',
#   's',
#   'resolve',
#   'to',
#   'aggressively',
#   'raise',
#   'interest',
#   'rates',
#   '.',
#   "here's",
#   'what',
#   'our',
#   'guests',
#   'on',
#   'bloomberg',
#   'tv',
#   'have',
#   'had',
#   'to',
#   'say',
#   'about',
#   '9.1',
#   '%',
#   'figure',
#   'https://t.co/he9qfgaow1',
#   'https://t.co/di1mm426lt'],
#  ['amazon',
#   '’',
#   's',
#   'uk',
#   'grocery',
#   'business',
#   'will',
#   'match',
#   'prices',
#   'on',
#   'hundreds',
#   'of',
#   'everyday',
#   'items',
#   'to',
#   'those',
#   'offered',
#   'by',
#   'rival',
#   'tesco',
#   'in',
#   'an',
#   'aggressive',
#   'move',
#   'against',
#   'britain',
#   '’',
#   's',
#   'largest',
#   'supermarket',
#   'chain',
#   'https://t.co/qqkffnp4cf'],
#  ['$',
#   'skhcf',
#   '$',
#   'skhhy',
#   '$',
#   'dgx',
#   '-',
#   'sonic',
#   'healthcare',
#   'begins',
#   'testing',
#   'for',
#   'monkeypox',
#   'https://t.co/iulnrncvic'],
#  ['inadequate',
#   'regulations',
#   'make',
#   'it',
#   'hard',
#   'for',
#   'cosmetic',
#   'surgery',
#   'patients',
#   'to',
#   'tell',
#   'if',
#   'they',
#   'are',
#   'getting',
#   'a',
#   'good',
#   'doctor',
#   'or',
#   'a',
#   'quack',
#   'https://t.co/sk8boisdyd'],
#  ['astorg',
#   'completes',
#   'acquisition',
#   'of',
#   'open',
#   'health',
#   'from',
#   'amulet',
#   'capital',
#   'partners',
#   'https://t.co/fogyvnrnjt',
#   'https://t.co/8aahphslps'],
#  ['$',
#   'six',
#   'aug',
#   '.',
#   '22.50',
#   'calls',
#   'up',
#   'over',
#   '3500x',
#   'now',
#   'as',
#   'a',
#   'top',
#   'iv',
#   'gainer',
#   'as',
#   'well'],
#  ['beef',
#   'steaks',
#   'and',
#   'pork',
#   'chops',
#   'were',
#   'some',
#   'of',
#   'the',
#   'only',
#   'goods',
#   'to',
#   'see',
#   'prices',
#   'fall',
#   'at',
#   'us',
#   'grocery',
#   'stores',
#   'last',
#   'month',
#   ',',
#   'according',
#   'to',
#   'government',
#   'data',
#   'released',
#   'wednesday',
#   'https://t.co/qdtvctbxzf'],
#  ['$',
#   'eose',
#   '$',
#   'staf',
#   '$',
#   'mrtn',
#   '-',
#   'eose',
#   ',',
#   'evex',
#   'among',
#   'top',
#   'industrial',
#   'movers',
#   'https://t.co/mzrw0wu92r'],
#  ['rapid',
#   'dose',
#   'therapeutics',
#   'provides',
#   'bi-weekly',
#   'mcto',
#   'status',
#   'update',
#   'https://t.co/8j70hykupk',
#   'https://t.co/kqnumlbs7v'],
#  ['dow',
#   'futures',
#   'drop',
#   '400',
#   'points',
#   'after',
#   'much',
#   'hotter-than-expected',
#   'inflation',
#   'report',
#   'https://t.co/mrocyzavrq'],
#  ['klas',
#   'technology',
#   'spotlight',
#   'report',
#   'gives',
#   'multiview',
#   'a',
#   'top',
#   'mark',
#   'for',
#   'erps',
#   'and',
#   'client',
#   'satisfaction',
#   'https://t.co/29zy1eyckz',
#   'https://t.co/igowsi9pus'],
#  ['sionic',
#   'launching',
#   'free',
#   'code',
#   'pay',
#   'mobile',
#   'app',
#   'for',
#   'local',
#   'merchants',
#   'https://t.co/tqz5xg1pol',
#   'https://t.co/cwiqt29umh'],
#  ['demand',
#   'solutions',
#   'recognized',
#   'for',
#   'tenth',
#   'year',
#   'with',
#   'top',
#   'supply',
#   'chain',
#   'project',
#   'award',
#   'https://t.co/icjfutkcog',
#   'https://t.co/dvqitt9dcf'],
#  ['$',
#   'mmm',
#   '-',
#   '3m',
#   'has',
#   '64th',
#   'annual',
#   'dividend',
#   'increase',
#   'despite',
#   'headwinds',
#   'and',
#   'legal',
#   'risk',
#   '.',
#   'https://t.co/irjwy4udoa',
#   '#trading',
#   '#investing',
#   '#economy'],
#  ['fed',
#   'governor',
#   'christopher',
#   'waller',
#   'said',
#   'he',
#   'backs',
#   'a',
#   'three-quarter',
#   'percentage-point',
#   'hike',
#   'in',
#   'the',
#   'benchmark',
#   'rate',
#   'later',
#   'this',
#   'month',
#   'after',
#   'the',
#   'latest',
#   'cpi',
#   'report',
#   ',',
#   'but',
#   'could',
#   'vote',
#   'for',
#   'more',
#   'aggressive',
#   'action',
#   'depending',
#   'on',
#   'further',
#   'data',
#   'https://t.co/u92fgm9hhf'],
#  ['traders',
#   'are',
#   'betting',
#   'on',
#   'bigger',
#   'losses',
#   'for',
#   'stocks',
#   'after',
#   'a',
#   'stretch',
#   'that',
#   'has',
#   'pushed',
#   'the',
#   's',
#   '&',
#   'p',
#   '500',
#   'toward',
#   'its',
#   'worst',
#   'start',
#   'to',
#   'a',
#   'year',
#   'in',
#   'nearly',
#   'a',
#   'century',
#   'https://t.co/o1bm4lwfhf'],
#  ['these',
#   'are',
#   'the',
#   'best',
#   'and',
#   'worst',
#   'countries',
#   'for',
#   'remote',
#   'working',
#   'https://t.co/lnqtb1xvoa'],
#  ['the',
#   'next',
#   'uk',
#   'prime',
#   'minister',
#   'will',
#   'have',
#   'big',
#   'problems',
#   'to',
#   'address',
#   '.',
#   "here's",
#   'what',
#   "we'd",
#   'ask',
#   'them',
#   '.',
#   'sign',
#   'up',
#   'for',
#   'the',
#   'readout',
#   'with',
#   'allegra',
#   'stratton',
#   'https://t.co/fpy4esoy3t'],
#  ['us',
#   'permian',
#   'oil',
#   'output',
#   'set',
#   'to',
#   'rise',
#   'in',
#   'august',
#   'to',
#   'highest',
#   'on',
#   'record',
#   '-',
#   'eia',
#   'us',
#   'bakken',
#   'oil',
#   'output',
#   'to',
#   'rise',
#   'in',
#   'august',
#   'to',
#   'highest',
#   'since',
#   'dec',
#   '2020',
#   '-',
#   'eia',
#   'us',
#   'eagle',
#   'ford',
#   'oil',
#   'output',
#   'to',
#   'rise',
#   'in',
#   'august',
#   'to',
#   'highest',
#   'since',
#   'april',
#   '2020',
#   '-',
#   'eia'],
#  ['raymond',
#   'james',
#   'says',
#   'bath',
#   '&',
#   'body',
#   'works',
#   'is',
#   'oversold',
#   'and',
#   'will',
#   'jump',
#   'nearly',
#   '70',
#   '%',
#   'from',
#   'here',
#   'https://t.co/spgpi6zvko'],
#  ['$',
#   'sfix',
#   '-',
#   'stitch',
#   'fix',
#   ':',
#   'no',
#   'rescue',
#   'in',
#   'sight',
#   '.',
#   'https://t.co/iddftpn8td',
#   '#investing',
#   '#business',
#   '#trading'],
#  ['spain',
#   'will',
#   'impose',
#   'an',
#   'exceptional',
#   'tax',
#   'on',
#   'banks',
#   'as',
#   'part',
#   'of',
#   'government',
#   'attempts',
#   'to',
#   'mitigate',
#   'the',
#   'economic',
#   'impact',
#   'of',
#   'the',
#   'war',
#   'in',
#   'ukraine',
#   'and',
#   'soaring',
#   'inflation',
#   'https://t.co/hurlblg6fx'],
#  ['uber',
#   'equity',
#   'alert',
#   ':',
#   'rosen',
#   'law',
#   'firm',
#   'encourages',
#   'uber',
#   'technologies',
#   ',',
#   'inc',
#   '.',
#   'investors',
#   'to',
#   'inquire',
#   'about',
#   'securities',
#   'class',
#   'action',
#   'investigation',
#   '–',
#   'uber',
#   'https://t.co/qoi6xixpbx',
#   'https://t.co/xukypibjjy'],
#  ['from',
#   'breakingviews',
#   '-',
#   'saudi',
#   'can',
#   'win',
#   'two',
#   'ways',
#   'in',
#   'global',
#   'energy',
#   'reshuffle',
#   'https://t.co/4asbafcgsn'],
#  ['$',
#   'spy',
#   '$',
#   'spx',
#   '$',
#   'es_f',
#   '#cpi',
#   '8:',
#   '30',
#   'am',
#   'est',
#   '!',
#   '🚨'],
#  ['goldman',
#   'sachs',
#   'ceo',
#   '@davidsolomon',
#   'says',
#   'inflation',
#   'is',
#   '‘',
#   'deeply',
#   'entrenched',
#   "'",
#   'in',
#   'the',
#   'global',
#   'economy'],
#  ['$',
#   'nbhc',
#   '-',
#   'nbh',
#   'holdings',
#   'gaap',
#   'eps',
#   'of',
#   '$',
#   '0.67',
#   'beats',
#   'by',
#   '$',
#   '0.03',
#   ',',
#   'revenue',
#   'of',
#   '$',
#   '72.78',
#   'm',
#   'beats',
#   'by',
#   '$',
#   '1.34',
#   'm',
#   'https://t.co/cesktyipcq'],
#  ['$',
#   'comdx',
#   ':',
#   'metals',
#   'settlement',
#   'prices',
#   'https://t.co/l4g2kdkwmm'],
#  ['$',
#   'acr',
#   '$',
#   'acr.pc',
#   '-',
#   '2',
#   '-',
#   'year',
#   '46',
#   '%',
#   'potential',
#   'return',
#   'with',
#   'preferred',
#   'series',
#   'c',
#   'from',
#   'acres',
#   'commercial',
#   'realty',
#   'corp',
#   '..',
#   'https://t.co/5tckxywkhw',
#   '#investing',
#   '#finance',
#   '#stocks'],
#  ['mortgage',
#   'boycotts',
#   'in',
#   'china',
#   'are',
#   'intensifying',
#   ',',
#   'and',
#   'the',
#   'question',
#   'is',
#   'how',
#   'far',
#   'they',
#   'will',
#   'spread',
#   'https://t.co/64skglhvjk'],
#  ['$',
#   'jbht',
#   '(',
#   '-2.0',
#   '%',
#   'pre',
#   ')',
#   'j',
#   '.',
#   'b',
#   '.',
#   'hunt',
#   'transport',
#   'services',
#   ',',
#   'inc',
#   '.',
#   'reports',
#   'u',
#   '.',
#   's',
#   '.',
#   'gaap',
#   'revenues',
#   ',',
#   'net',
#   'earnings',
#   'and',
#   'earnings',
#   'per',
#   'share',
#   'for',
#   'the',
#   'second',
#   'quarter',
#   '2022',
#   '-',
#   'bw',
#   'https://t.co/ahq8i5lc5z'],
#  ['united',
#   'airlines',
#   'falls',
#   'short',
#   'of',
#   'profit',
#   'estimates',
#   'on',
#   'higher',
#   'costs',
#   'https://t.co/gpkjzyqt8n',
#   'https://t.co/moo127zcb3'],
#  ['motive',
#   'partners',
#   'raises',
#   '$',
#   '2.5',
#   'billion',
#   'https://t.co/bawnuaod7b',
#   'https://t.co/lypzjwivaz'],
#  ['$',
#   'sumrx',
#   ':',
#   'asian',
#   'markets',
#   'close',
#   ':',
#   'nikkei',
#   '-1.8',
#   '%',
#   ',',
#   'hang',
#   'seng',
#   '-1.3',
#   '%',
#   ',',
#   'shanghai',
#   '-1.0',
#   '%',
#   'https://t.co/3jms8by25r'],
#  ['$',
#   'xlk',
#   '-',
#   'credit',
#   'suisse',
#   'wary',
#   'on',
#   'big',
#   'tech',
#   'earnings',
#   ',',
#   'but',
#   'oppenheimer',
#   'highlights',
#   'charts',
#   'https://t.co/uswylhiq3y'],
#  ['a',
#   'sweeping',
#   'bill',
#   'that',
#   'would',
#   'overhaul',
#   'how',
#   'the',
#   'crypto',
#   'industry',
#   'is',
#   'regulated',
#   'by',
#   'washington',
#   'is',
#   'unlikely',
#   'to',
#   'be',
#   'voted',
#   'on',
#   'this',
#   'year',
#   'by',
#   'the',
#   'us',
#   'senate',
#   ',',
#   'according',
#   'to',
#   'one',
#   'of',
#   'the',
#   'lawmakers',
#   'driving',
#   'the',
#   'effort',
#   'https://t.co/5jsluahb32'],
#  ['european',
#   'stocks',
#   'head',
#   'for',
#   'higher',
#   'open',
#   'as',
#   'u',
#   '.',
#   's',
#   '.',
#   'rally',
#   'lifts',
#   'global',
#   'sentiment',
#   'https://t.co/eghprgevr0'],
#  ['oil',
#   'jumps',
#   'as',
#   'soft',
#   'dollar',
#   'and',
#   'tight',
#   'supply',
#   'supports',
#   '-',
#   'si',
#   'https://t.co/m95bkdolrc'],
#  ['wall',
#   'street',
#   'breakfast',
#   ':',
#   'earnings',
#   'evaluation',
#   '.',
#   'https://t.co/b8ad5cbj9s',
#   '#markets',
#   '#investing',
#   '#stocks'],
#  ["it's",
#   'rate',
#   'decision',
#   'day',
#   'in',
#   'south',
#   'africa',
#   '—',
#   "here's",
#   'what',
#   'to',
#   'expect',
#   'https://t.co/gbribojare',
#   'https://t.co/bspjprbq3k'],
#  ['united',
#   'airlines',
#   'posts',
#   'profit',
#   'on',
#   'travel',
#   'surge',
#   'but',
#   'holds',
#   'back',
#   'on',
#   'flight',
#   'growth',
#   'https://t.co/jwlyxzrvku'],
#  ['for',
#   'the',
#   'first',
#   'time',
#   'in',
#   'well',
#   'over',
#   'a',
#   'year',
#   ',',
#   'funds',
#   'like',
#   'the',
#   '$',
#   '21',
#   'billion',
#   'ishares',
#   'short',
#   'treasury',
#   'bond',
#   'etf',
#   'are',
#   'reliably',
#   'paying',
#   'out',
#   'dividends',
#   'https://t.co/jallyoylel'],
#  ['italy',
#   '’',
#   's',
#   'economy',
#   'probably',
#   'expanded',
#   'about',
#   '0.5',
#   '%',
#   'in',
#   'the',
#   'second',
#   'quarter',
#   ',',
#   'with',
#   'households',
#   'benefiting',
#   'from',
#   'easing',
#   'coronavirus',
#   'restrictions',
#   ',',
#   'the',
#   'central',
#   'bank',
#   'says',
#   'https://t.co/ywhnmhb7p2'],
#  ['moody',
#   '’',
#   's',
#   'chief',
#   'economist',
#   'says',
#   'he',
#   '’',
#   's',
#   'never',
#   'seen',
#   'so',
#   'many',
#   'people',
#   'convinced',
#   'that',
#   'a',
#   'recession',
#   'is',
#   'imminent',
#   'https://t.co/uch92erqdi'],
#  ['$',
#   'th',
#   '-',
#   'target',
#   'hospitality',
#   ':',
#   'strong',
#   'growth',
#   ',',
#   'investors',
#   'to',
#   'expect',
#   'more',
#   'going',
#   'forward',
#   '.',
#   'https://t.co/cdyslzp0qd',
#   '#business',
#   '#stockmarket',
#   '#markets'],
#  ['$',
#   'gs',
#   'forecasts',
#   'a',
#   '3.8',
#   '%',
#   'unemployment',
#   'rate',
#   'by',
#   'the',
#   'year',
#   '2023',
#   '.',
#   'https://t.co/hxoemi8fkl'],
#  ['apparel',
#   'prices',
#   'remain',
#   'high',
#   'even',
#   'as',
#   'retailers',
#   'use',
#   'markdowns',
#   'to',
#   'clear',
#   'excess',
#   'inventory',
#   'https://t.co/5doawpgzsj'],
#  ['watch',
#   ':',
#   'microsoft',
#   'co-founder',
#   'bill',
#   'gates',
#   'is',
#   'donating',
#   '$',
#   '20',
#   'billion',
#   'to',
#   'the',
#   'bill',
#   '&',
#   'melinda',
#   'gates',
#   'foundation',
#   'to',
#   'help',
#   'boost',
#   'his',
#   'charity',
#   '’',
#   's',
#   'annual',
#   'payouts',
#   'by',
#   '50',
#   '%',
#   'to',
#   '$',
#   '9',
#   'billion',
#   'by',
#   '2026',
#   'https://t.co/evvtnxuaeo',
#   'https://t.co/mfd7irgkro'],
#  ['$',
#   'etwo',
#   '-',
#   'e2open',
#   ':',
#   'harmed',
#   'by',
#   'its',
#   'spac',
#   'status',
#   'among',
#   'other',
#   'misunderstandings',
#   '.',
#   'https://t.co/ihudc4ujkw',
#   '#economy',
#   '#stockmarket',
#   '#trading'],
#  ['british',
#   'businesses',
#   'lead',
#   'their',
#   'european',
#   'counterparts',
#   'in',
#   'terms',
#   'of',
#   'confidence',
#   'about',
#   'the',
#   'future',
#   'even',
#   'after',
#   'an',
#   'index',
#   'of',
#   'optimism',
#   'plunged',
#   'by',
#   'half',
#   'to',
#   'a',
#   'record',
#   'low',
#   'https://t.co/bn4rnflnkc'],
#  ['ford',
#   'just',
#   'unveiled',
#   'the',
#   'f',
#   '-',
#   '150',
#   'raptor',
#   'r',
#   ',',
#   'a',
#   'new',
#   'version',
#   'of',
#   'its',
#   'high-performance',
#   ',',
#   'off-road',
#   'pickup',
#   'with',
#   'a',
#   'supercharged',
#   '5.2-',
#   'liter',
#   'v',
#   '-',
#   '8',
#   'engine',
#   'that',
#   'produces',
#   '700',
#   'horsepower',
#   'and',
#   '640',
#   'foot-pounds',
#   'of',
#   'torque',
#   '.',
#   'take',
#   'a',
#   'look',
#   ':',
#   'https://t.co/4srerxe88q',
#   'https://t.co/ya6takwooz'],
#  ['$', 'crox', '$', 'crnc', '$', 'amrn'],
#  ['senate',
#   'democrats',
#   'are',
#   'urging',
#   'the',
#   'white',
#   'house',
#   'to',
#   'declare',
#   'a',
#   '“',
#   'climate',
#   'emergency',
#   ',',
#   '”',
#   'which',
#   'will',
#   'give',
#   'biden',
#   'the',
#   'authority',
#   'to',
#   'redirect',
#   'funds',
#   'for',
#   'clean',
#   'energy',
#   'projects',
#   'and',
#   'restrict',
#   'offshore',
#   'oil',
#   'drilling',
#   'https://t.co/xmlt3xfmco',
#   'https://t.co/iak88i4x2g'],
#  ['$',
#   'rtppf',
#   '$',
#   'rio',
#   '$',
#   'rtntf',
#   '-',
#   'rio',
#   'tinto',
#   ':',
#   'q2',
#   'production',
#   'report',
#   'analysis',
#   '.',
#   'https://t.co/xzuesdfmeh',
#   '#finance',
#   '#trading',
#   '#business'],
#  ['india',
#   'is',
#   'on',
#   'track',
#   'to',
#   'overtake',
#   'china',
#   'as',
#   'the',
#   "world's",
#   'most',
#   'populous',
#   'country',
#   'in',
#   '2023',
#   ',',
#   'according',
#   'to',
#   'a',
#   'u',
#   '.',
#   'n',
#   '.',
#   'report',
#   '.',
#   'https://t.co/gizgmngf9v'],
#  ['biden',
#   'says',
#   'pentagon',
#   'does',
#   'not',
#   'support',
#   'visit',
#   'by',
#   'pelosi',
#   'to',
#   'taiwan',
#   'https://t.co/iswzldrmcx'],
#  ['$',
#   'vcigf',
#   '-',
#   'vitreous',
#   'glass',
#   'declares',
#   '$',
#   '0.08',
#   'dividend',
#   'https://t.co/0d7trcp7q1'],
#  ['italian',
#   'markets',
#   'are',
#   'set',
#   'for',
#   'more',
#   'turbulence',
#   'as',
#   'a',
#   'political',
#   'crisis',
#   'deepens',
#   'just',
#   'as',
#   'the',
#   'ecb',
#   'gets',
#   'ready',
#   'to',
#   'hike',
#   'interest',
#   'rates',
#   'for',
#   'the',
#   'first',
#   'time',
#   'in',
#   'a',
#   'decade',
#   'https://t.co/stwh7stpp1'],
#  ['listen',
#   'now',
#   ':',
#   'netflix',
#   'names',
#   'microsoft',
#   'as',
#   'its',
#   'partner',
#   'to',
#   'serve',
#   'ads',
#   '.',
#   'what',
#   'could',
#   'it',
#   'mean',
#   'for',
#   'both',
#   'companies',
#   '?',
#   'listen',
#   'and',
#   'follow',
#   'the',
#   '@cnbctheexchange',
#   'podcast',
#   'here',
#   'or',
#   'on',
#   'your',
#   'favorite',
#   'podcast',
#   'platform',
#   ':',
#   'https://t.co/czvin33ef7',
#   'https://t.co/lw8ndonesr'],
#  ['investors',
#   '’',
#   'tax',
#   'losses',
#   'soar',
#   'in',
#   'market',
#   'turmoil',
#   'https://t.co/jycegwxhjj'],
#  ['$',
#   'mtb',
#   '-',
#   'm',
#   '&',
#   't',
#   'bank',
#   'q2',
#   '2022',
#   'earnings',
#   'preview',
#   'https://t.co/xfw5xp0ij1'],
#  ['the',
#   'old',
#   'rule',
#   'that',
#   'you',
#   "shouldn't",
#   'spend',
#   'more',
#   'than',
#   '50',
#   '%',
#   'of',
#   'your',
#   'income',
#   'on',
#   'necessities',
#   'is',
#   'being',
#   'thrown',
#   'out',
#   'the',
#   'window',
#   'https://t.co/zvsyfbja28'],
#  ['$', 'boxd', 'looks', 'ready', 'for', 'more', '...'],
#  ['ge',
#   'unveils',
#   'brand',
#   'names',
#   'for',
#   'three',
#   'planned',
#   'future',
#   'public',
#   'companies',
#   'https://t.co/bkm9sy2xbq',
#   'https://t.co/azp7eefjzd'],
#  ['unitedlex',
#   'launches',
#   'predictive',
#   'modeling',
#   'to',
#   'forecast',
#   'legal',
#   'department',
#   'performance',
#   'https://t.co/pdfdof0vdy',
#   'https://t.co/rbd1qlupwp'],
#  ['china',
#   '’',
#   's',
#   'central',
#   'bank',
#   'keeps',
#   'benchmark',
#   'rates',
#   'despite',
#   'rising',
#   'risks',
#   'https://t.co/srquwyizre'],
#  ['$',
#   'fast',
#   'indicated',
#   '47',
#   'after',
#   'results',
#   ',',
#   'should',
#   'be',
#   'a',
#   'pretty',
#   'solid',
#   'return',
#   ',',
#   'spreads',
#   'were',
#   'cheap'],
#  ['note',
#   'to',
#   'the',
#   'g',
#   '-',
#   '7',
#   'and',
#   'the',
#   'us',
#   'treasury',
#   'secretary',
#   ':',
#   'russia',
#   'is',
#   'still',
#   'raking',
#   'it',
#   'in',
#   'from',
#   'oil',
#   ',',
#   'even',
#   'if',
#   'its',
#   'exports',
#   'are',
#   'showing',
#   'signs',
#   'of',
#   'ebbing',
#   'https://t.co/ghwwmrb8pl'],
#  ['$',
#   'ctxs',
#   ':',
#   'citrix',
#   'systems',
#   'provides',
#   'update',
#   'on',
#   'approval',
#   'process',
#   'for',
#   'the',
#   'pending',
#   'acquisition',
#   'by',
#   'affiliates',
#   'of',
#   'vista',
#   'equity',
#   '...',
#   'https://t.co/sm9duqj4vp'],
#  ['$',
#   'aer',
#   ':',
#   'aercap',
#   'confirms',
#   'order',
#   'for',
#   'five',
#   'additional',
#   'boeing',
#   '(',
#   'ba',
#   ')',
#   '787-9',
#   'dreamliners',
#   'https://t.co/nsqdfkjhzu'],
#  ['account',
#   'of',
#   'the',
#   'monetary',
#   'policy',
#   'meeting',
#   'of',
#   'the',
#   'governing',
#   'council',
#   'of',
#   'the',
#   'ecb',
#   'of',
#   '8-9',
#   'june',
#   '2022',
#   'https://t.co/uelr6ezt6l'],
#  ['$',
#   'gldm',
#   '$',
#   'pplt',
#   '-',
#   'the',
#   'best',
#   '2',
#   'precious',
#   'metals',
#   'etfs',
#   'for',
#   'h2',
#   '2022',
#   'and',
#   'beyond',
#   '.',
#   'https://t.co/rlk9xd0whz',
#   '#trading',
#   '#investing',
#   '#markets'],
#  ['senior',
#   'us',
#   'officials',
#   'are',
#   'spreading',
#   'out',
#   'across',
#   'asia',
#   'following',
#   'secretary',
#   'of',
#   'state',
#   'antony',
#   'blinken',
#   '’',
#   's',
#   'brief',
#   'trip',
#   'to',
#   'the',
#   'region',
#   ',',
#   'in',
#   'the',
#   'next',
#   'phase',
#   'of',
#   'a',
#   'diplomatic',
#   'charm',
#   'offensive',
#   'https://t.co/mzyxlcpmdz'],
#  ['traders',
#   'trim',
#   'expectation',
#   'for',
#   'next',
#   'fed',
#   'rate',
#   'hike',
#   'to',
#   '75',
#   'basis',
#   'points',
#   'from',
#   '100',
#   'bps',
#   'https://t.co/irakdyyelq'],
#  ['kalvista',
#   'pharmaceuticals',
#   'to',
#   'present',
#   'at',
#   '1st',
#   'annual',
#   'h',
#   '.',
#   'c',
#   '.',
#   'wainwright',
#   'hereditary',
#   'angioedema',
#   'conference',
#   'https://t.co/b9aj6mkbvx',
#   'https://t.co/cjk1hwjjcq'],
#  ['investigation',
#   'alert',
#   ':',
#   'the',
#   'schall',
#   'law',
#   'firm',
#   'encourages',
#   'investors',
#   'in',
#   'stepstone',
#   'group',
#   'inc',
#   '.',
#   'with',
#   'losses',
#   'to',
#   'contact',
#   'the',
#   'firm',
#   'https://t.co/ctymc9za1c',
#   'https://t.co/bpkksp1b5o'],
#  ['$',
#   'bkr',
#   '-',
#   'baker',
#   'hughes',
#   'plunges',
#   'as',
#   'shortages',
#   ',',
#   'inflation',
#   'add',
#   'to',
#   'losses',
#   'https://t.co/gndtc2fw04'],
#  ['bailey',
#   'pledges',
#   'to',
#   'bring',
#   'uk',
#   'inflation',
#   'back',
#   'down',
#   'to',
#   '2',
#   '%',
#   'target',
#   'https://t.co/qj1mvdqbig'],
#  ['the',
#   'small',
#   'but',
#   'growing',
#   'safe',
#   'cities',
#   'movement',
#   'is',
#   'looking',
#   'to',
#   'los',
#   'angeles',
#   'to',
#   'help',
#   'stop',
#   'the',
#   'construction',
#   'of',
#   'new',
#   'gas',
#   'stations',
#   'across',
#   'north',
#   'america',
#   'https://t.co/szgdjjzvno',
#   'via',
#   '@citylab'],
#  ['$',
#   'for',
#   '-',
#   'forestar',
#   'group',
#   'inc',
#   '.',
#   '2022',
#   'q2',
#   '-',
#   'results',
#   '-',
#   'earnings',
#   'call',
#   'presentation',
#   '.',
#   'https://t.co/sadgkejycw',
#   '#investing',
#   '#economy',
#   '#stocks'],
#  ['$',
#   'cgrn',
#   '-',
#   'capstone',
#   'green',
#   'energy',
#   'surges',
#   'on',
#   'new',
#   '600',
#   'kw',
#   'energy-as-a-service',
#   'contract',
#   'https://t.co/k8tjtorhvt'],
#  ['$',
#   'ibm',
#   'shares',
#   'fall',
#   'amid',
#   'reporting',
#   'a',
#   'q2',
#   'earnings',
#   'beat',
#   ',',
#   'cuttings',
#   'its',
#   'cash',
#   'forecasts',
#   '.',
#   'https://t.co/qnqvnfgzlx'],
#  ['while',
#   'the',
#   'sec',
#   'climate',
#   'proposal',
#   'has',
#   'support',
#   'from',
#   'environmental',
#   'defenders',
#   ',',
#   'democrats',
#   'and',
#   'some',
#   'of',
#   'the',
#   'largest',
#   'public',
#   'pension',
#   'funds',
#   ',',
#   'it',
#   '’',
#   's',
#   'been',
#   'attacked',
#   'by',
#   'business',
#   'lobbying',
#   'groups',
#   'and',
#   'republicans',
#   'https://t.co/hzovx5wiep'],
#  ['$',
#   'pine',
#   '-',
#   'alpine',
#   'income',
#   'property',
#   'trust',
#   'q2',
#   '2022',
#   'earnings',
#   'preview',
#   'https://t.co/nkyt91qxri'],
#  ['two',
#   'candidates',
#   'remain',
#   'in',
#   'the',
#   'battle',
#   'to',
#   'succeed',
#   'boris',
#   'johnson',
#   'as',
#   'leader',
#   'of',
#   'the',
#   'uk',
#   'conservative',
#   'party',
#   'and',
#   'prime',
#   'minister',
#   ',',
#   'as',
#   'betting',
#   'companies',
#   'adjust',
#   'their',
#   'odds',
#   'during',
#   'the',
#   'twists',
#   'and',
#   'turns',
#   'of',
#   'the',
#   'leadership',
#   'race',
#   '.',
#   '@lizzzburden',
#   'has',
#   'the',
#   'details',
#   'https://t.co/vrjsznp45i',
#   'https://t.co/xec9otlkhf'],
#  ['$',
#   'blkb',
#   ':',
#   'blackbaud',
#   'names',
#   'kevin',
#   'gregoire',
#   'as',
#   'coo',
#   'https://t.co/dch5f5ojna'],
#  ['if',
#   'bitcoin',
#   'believers',
#   'want',
#   'their',
#   'dreams',
#   'to',
#   'come',
#   'true',
#   ',',
#   'they',
#   'need',
#   'to',
#   'give',
#   'it',
#   'a',
#   'rest',
#   'https://t.co/wcbndechnc'],
#  ['dow',
#   'slumps',
#   '500',
#   'points',
#   'as',
#   'traders',
#   'worry',
#   'about',
#   'larger',
#   'rate',
#   'hikes',
#   ',',
#   'jpmorgan',
#   'falls',
#   'after',
#   'earnings',
#   'https://t.co/slebq3oe4o'],
#  ['$', 'wires', ':', 'on', 'the', 'wires', 'https://t.co/dtruoyhtpo'],
#  ['the',
#   'committee',
#   '’',
#   's',
#   'thursday',
#   'evening',
#   'hearing',
#   'will',
#   'examine',
#   'the',
#   'three-hour',
#   'plus',
#   'stretch',
#   'when',
#   'trump',
#   'failed',
#   'to',
#   'act',
#   'as',
#   'a',
#   'mob',
#   'of',
#   'supporters',
#   'stormed',
#   'the',
#   'capitol',
#   '.',
#   'it',
#   'will',
#   'be',
#   'the',
#   'first',
#   'hearing',
#   'in',
#   'prime',
#   'time',
#   'since',
#   'the',
#   'june',
#   '9',
#   'debut',
#   'that',
#   'was',
#   'viewed',
#   'by',
#   '20',
#   'million',
#   'people',
#   '.',
#   'https://t.co/jux3l32e4a'],
#  ['icymi',
#   ':',
#   '@federalreserve',
#   'developed',
#   'the',
#   'expected',
#   'losses',
#   'estimator',
#   '(',
#   'ele',
#   ')',
#   'tool',
#   'for',
#   'community',
#   'banks',
#   'as',
#   'they',
#   'transition',
#   'to',
#   'the',
#   'current',
#   'expected',
#   'credit',
#   'losses',
#   '(',
#   'cecl',
#   ')',
#   'standard',
#   'in',
#   '2023',
#   '.',
#   'to',
#   'learn',
#   'more',
#   'about',
#   'ele',
#   ':',
#   'https://t.co/cilnibtehm',
#   'https://t.co/xfg87hweho'],
#  ['us',
#   'auto',
#   'safety',
#   'regulators',
#   'are',
#   'investigating',
#   'a',
#   '2021',
#   'tesla',
#   'model',
#   'y',
#   'crash',
#   'that',
#   'killed',
#   'a',
#   'motorcyclist',
#   'in',
#   'california',
#   'earlier',
#   'this',
#   'month',
#   'https://t.co/2l2riukkwr'],
#  ['gas',
#   'prices',
#   ':',
#   'the',
#   '‘',
#   'biggest',
#   'factor',
#   "'",
#   'is',
#   'vladimir',
#   'putin',
#   ',',
#   'says',
#   'analyst',
#   'https://t.co/7gjto6raa1',
#   'by',
#   '@ines_ferre',
#   'https://t.co/0gf23fk9iq'],
#  ['mariadb',
#   'drafts',
#   'top',
#   'financial',
#   'talent',
#   'ahead',
#   'of',
#   'becoming',
#   'a',
#   'public',
#   'company',
#   'https://t.co/joyzarduqn',
#   'https://t.co/l8cb2cebj9'],
#  ['$',
#   'tgi',
#   '-',
#   'triumph',
#   'secures',
#   'contract',
#   'from',
#   'edecus',
#   'for',
#   'the',
#   'uh',
#   '-',
#   '60',
#   'black',
#   'hawk',
#   'and',
#   'ah',
#   '-',
#   '64',
#   'apache',
#   'fleets',
#   'https://t.co/lxlwpqn5vs'],
#  ['china',
#   '’',
#   's',
#   'economy',
#   'narrowly',
#   'escaped',
#   'a',
#   'contraction',
#   'in',
#   'the',
#   'second',
#   'quarter',
#   'as',
#   'president',
#   'xi',
#   'jinping',
#   '’',
#   's',
#   'zero-covid',
#   'policy',
#   'stoked',
#   'expectations',
#   'that',
#   'beijing',
#   'would',
#   'inject',
#   'hundreds',
#   'of',
#   'billions',
#   'of',
#   'dollars',
#   'of',
#   'stimulus',
#   'to',
#   'shore',
#   'up',
#   'growth',
#   'https://t.co/2l7ywfywpc',
#   'https://t.co/hcuouvgnc5'],
#  ['$',
#   'gme',
#   '-',
#   'gamestop',
#   '4',
#   '-',
#   'for',
#   '-',
#   '1',
#   'stock',
#   'split',
#   ':',
#   'what',
#   'investors',
#   'need',
#   'to',
#   'know',
#   '.',
#   'https://t.co/1afgwyxfii',
#   '#investing',
#   '#markets',
#   '#finance'],
#  ['spdr',
#   'gold',
#   'trust',
#   'gld',
#   'reports',
#   'holdings',
#   'down',
#   '0.32',
#   'pct',
#   ',',
#   'or',
#   '3.19',
#   'tonnes',
#   ',',
#   'to',
#   '1,005',
#   '.',
#   '87',
#   'tonnes',
#   'by',
#   'july',
#   '20'],
#  ['u',
#   '.',
#   's',
#   '.',
#   'futures',
#   'signal',
#   'further',
#   'gains',
#   'as',
#   'netflix',
#   'bounces',
#   'https://t.co/aszw66ufmg'],
#  ['uk',
#   'regulator',
#   'opens',
#   'probe',
#   'into',
#   'media',
#   'groups',
#   'over',
#   'sports',
#   'broadcasts',
#   'https://t.co/ceyzfo02xm'],
#  ['the',
#   'euro',
#   'is',
#   'edging',
#   'closer',
#   'toward',
#   'parity',
#   'with',
#   'the',
#   'us',
#   'dollar',
#   'as',
#   'energy',
#   'concerns',
#   'and',
#   'the',
#   'risk',
#   'of',
#   'recession',
#   'weigh',
#   'on',
#   'the',
#   'outlook',
#   'for',
#   'the',
#   'euro',
#   'area',
#   'https://t.co/0rc7bithnc'],
#  ['mio',
#   ',',
#   'a',
#   'liquid',
#   'water',
#   'enhancer',
#   ',',
#   'and',
#   'gaming',
#   'community',
#   'network',
#   'partner',
#   'to',
#   'launch',
#   'the',
#   'mio',
#   'level',
#   'up',
#   'challenge',
#   ',',
#   'pitting',
#   'gaming',
#   'stars',
#   'and',
#   'celebrities',
#   'against',
#   'one',
#   'another',
#   'to',
#   'win',
#   'cash',
#   'prizes',
#   'https://t.co/aeuuo77nlr',
#   'https://t.co/hslm3xj5pq'],
#  ['uk',
#   'strips',
#   '£',
#   '400mn',
#   'of',
#   'greensill',
#   'loans',
#   'to',
#   'sanjeev',
#   'gupta',
#   'of',
#   'state',
#   'guarantee',
#   'https://t.co/js9sli2fyw'],
#  ['u',
#   '.',
#   's',
#   'initial',
#   'jobless',
#   'claims',
#   'actual',
#   ':',
#   '244k',
#   'vs',
#   '235k',
#   'previous',
#   ';',
#   'est',
#   '235k',
#   'u',
#   '.',
#   's',
#   'continuing',
#   'jobless',
#   'claims',
#   'actual',
#   ':',
#   '1331k',
#   'vs',
#   '1375k',
#   'previous',
#   ';',
#   'est',
#   '1380k'],
#  ['$', 'bondx', ':', 'auction', 'out', 'https://t.co/shc4wt93d6'],
#  ['boeing',
#   'is',
#   'tempering',
#   'expectations',
#   'for',
#   'commercial',
#   'aircraft',
#   'demand',
#   'in',
#   'the',
#   'coming',
#   'decades',
#   ',',
#   'as',
#   'the',
#   'prospect',
#   'of',
#   'lower',
#   'global',
#   'economic',
#   'growth',
#   'and',
#   'uncertainty',
#   'surrounding',
#   'russia',
#   'pressure',
#   'jet',
#   'deliveries',
#   'https://t.co/if4qzihwns'],
#  ['us',
#   'president',
#   'biden',
#   'meet',
#   'with',
#   'palestinian',
#   'president',
#   'mahmoud',
#   'abbas',
#   'during',
#   'his',
#   'visit',
#   'to',
#   'the',
#   'middle',
#   'east',
#   ',',
#   'and',
#   'pledged',
#   'to',
#   'bring',
#   'the',
#   'palestinians',
#   'and',
#   'israelis',
#   'sides',
#   'together',
#   'https://t.co/flxsnc9nx5',
#   'https://t.co/ocit3mmrzz'],
#  ['$', '378p'],
#  ['the',
#   'regents',
#   'of',
#   'the',
#   'university',
#   'of',
#   'california',
#   'awards',
#   'yuja',
#   'systemwide',
#   'purchase',
#   'agreement',
#   'https://t.co/qd6w4jl6u5',
#   'https://t.co/ahmmkiu3mp'],
#  ['$',
#   'ups',
#   '$',
#   'expd',
#   '$',
#   'chrw',
#   '-',
#   'ups',
#   'downgraded',
#   'to',
#   'sell',
#   ',',
#   'knight-swift',
#   'upgraded',
#   'at',
#   'wolfe',
#   'research',
#   'https://t.co/upgud9fweu'],
#  ['$',
#   'bynd',
#   '-',
#   'beyond',
#   'meat',
#   ':',
#   'in',
#   'the',
#   'meat',
#   'grinder',
#   '.',
#   'https://t.co/w3qc7fjbns',
#   '#finance',
#   '#stockmarket',
#   '#stocks'],
#  ['$',
#   'tffp',
#   '-',
#   'tff',
#   'pharmaceuticals',
#   'expands',
#   'r',
#   '&',
#   'd',
#   'operations',
#   'with',
#   'new',
#   'austin',
#   'facility',
#   'https://t.co/z52zyfie4p'],
#  ['#wti',
#   'crude',
#   'oil',
#   ',',
#   'first',
#   'weekly',
#   'close',
#   'below',
#   '100',
#   'since',
#   '2/25',
#   '.',
#   '$',
#   'sco',
#   '$',
#   'ery',
#   'https://t.co/apib0ibdll'],
#  ['$',
#   'ofg',
#   '$',
#   'ofg.pa',
#   '-',
#   'ofg',
#   'bancorp',
#   '2022',
#   'q2',
#   '-',
#   'results',
#   '-',
#   'earnings',
#   'call',
#   'presentation',
#   '.',
#   'https://t.co/ygzs5xdial',
#   '#trading',
#   '#markets',
#   '#investing'],
#  ['u',
#   '.',
#   's',
#   '.',
#   'sec',
#   'extends',
#   'period',
#   'to',
#   'approve',
#   'or',
#   'disapprove',
#   'listing',
#   'of',
#   'ark',
#   '21shares',
#   'bitcoin',
#   'etf',
#   'to',
#   'aug',
#   '.',
#   '30'],
#  ['$',
#   'bcs',
#   '-',
#   'barclays',
#   ':',
#   'fundamentals',
#   'indicate',
#   'strong',
#   'upside',
#   '.',
#   'https://t.co/2syvdyeogb',
#   '#economy',
#   '#stocks',
#   '#business'],
#  ['the',
#   'asset-management',
#   'firm',
#   'matthews',
#   'asia',
#   'is',
#   'diving',
#   'into',
#   'the',
#   'etf',
#   'market',
#   'with',
#   'the',
#   'launch',
#   'of',
#   'three',
#   'funds',
#   'focused',
#   'on',
#   'china',
#   ',',
#   'asia',
#   'and',
#   'emerging',
#   'markets',
#   'https://t.co/omfakj6b2w'],
#  ['$',
#   'msft',
#   '-',
#   'microsoft',
#   'is',
#   'a',
#   'buy',
#   'before',
#   'earnings',
#   '.',
#   "here's",
#   'why',
#   '.',
#   'https://t.co/dcjathqtb3',
#   '#stockmarket',
#   '#investing',
#   '#business'],
#  ['@michaelnausscmt',
#   'pre',
#   'release',
#   '?',
#   'no',
#   'such',
#   'thing',
#   ',',
#   'but',
#   'you',
#   'will',
#   'get',
#   'one',
#   'of',
#   'the',
#   'first',
#   'copies',
#   '!'],
#  ['penny',
#   'mordaunt',
#   'attacks',
#   'tory',
#   'leadership',
#   'rivals',
#   'ahead',
#   'of',
#   'mps',
#   '’',
#   'final',
#   'vote',
#   'https://t.co/cuestundjf'],
#  ['siemens',
#   'has',
#   'the',
#   'responsibility',
#   'for',
#   'transporting',
#   'a',
#   'turbine',
#   'back',
#   'from',
#   'canada',
#   'that',
#   'is',
#   'critical',
#   'to',
#   'restoring',
#   'russian',
#   'gas',
#   'flow',
#   'through',
#   'the',
#   'nord',
#   'stream',
#   '1',
#   'pipeline',
#   ',',
#   'the',
#   'german',
#   'government',
#   'says',
#   'https://t.co/xufwgmjfip'],
#  ['the',
#   'inflation',
#   'rate',
#   'for',
#   'goods',
#   'purchased',
#   'online',
#   'in',
#   'the',
#   'us',
#   'slowed',
#   'sharply',
#   'last',
#   'month',
#   'while',
#   'food',
#   'prices',
#   'increased',
#   'at',
#   'the',
#   'fastest',
#   'pace',
#   'on',
#   'record',
#   ',',
#   'the',
#   'adobe',
#   'digital',
#   'price',
#   'index',
#   'shows',
#   'https://t.co/ajnzbrikla'],
#  ['the',
#   'cryptocurrency',
#   'market',
#   'has',
#   'lost',
#   'more',
#   'than',
#   '$',
#   '2,000',
#   ',',
#   '000,000',
#   ',',
#   '000',
#   '😅',
#   'https://t.co/bblyk2gszs'],
#  ['bank',
#   'of',
#   'new',
#   'york',
#   'mellon',
#   'uk',
#   'regulatory',
#   'announcement',
#   ':',
#   'frn',
#   'variable',
#   'rate',
#   'fix',
#   'https://t.co/uh75t8lqcd',
#   'https://t.co/zw3ot38gr1'],
#  ['grant',
#   'thornton',
#   'names',
#   'new',
#   'office',
#   'managing',
#   'partners',
#   'for',
#   'boston',
#   ',',
#   'cleveland',
#   'and',
#   'tulsa',
#   'https://t.co/h8bvwzuuwu',
#   'https://t.co/ugyhat9vm9'],
#  ['recent',
#   'gains',
#   'in',
#   'us',
#   'payrolls',
#   ',',
#   'including',
#   'a',
#   'stronger-than-expected',
#   'june',
#   'advance',
#   ',',
#   'probably',
#   'exaggerate',
#   'current',
#   'employment',
#   'growth',
#   ',',
#   'according',
#   'to',
#   'goldman',
#   'sachs',
#   'https://t.co/mpnjqymqxq'],
#  ['mcgill',
#   'and',
#   'partners',
#   'choose',
#   'cybercube',
#   'for',
#   'cyber',
#   'risk',
#   'analytics',
#   'https://t.co/4gcy1r4r3k',
#   'https://t.co/5hzdjgcfvz'],
#  ['joe',
#   'biden',
#   'seeks',
#   'reset',
#   'on',
#   'saudi',
#   'arabia',
#   'as',
#   'oil',
#   'tensions',
#   'flare',
#   'https://t.co/hkad5hrmzc'],
#  ['seems',
#   'a',
#   'miss',
#   'on',
#   'all',
#   'fronts',
#   'for',
#   'tencent',
#   '.',
#   'naspers',
#   '-5.2',
#   '%',
#   'after',
#   'tencent',
#   'q1',
#   'earnings'],
#  ['$',
#   'evfm',
#   '13g',
#   'filed',
#   'by',
#   'todd',
#   'stewart',
#   'cox',
#   '9.29',
#   '%',
#   'stake'],
#  ['the',
#   'number',
#   'of',
#   'profit',
#   'warnings',
#   'issued',
#   'by',
#   'uk-listed',
#   'firms',
#   'rose',
#   '66',
#   '%',
#   'in',
#   'the',
#   'first',
#   'half',
#   'of',
#   'the',
#   'year',
#   'amid',
#   'higher',
#   'costs',
#   ',',
#   'according',
#   'to',
#   'a',
#   'report',
#   'by',
#   'ey',
#   'https://t.co/a95tqxnyil'],
#  ['former',
#   'employees',
#   'say',
#   'issues',
#   'plagued',
#   'the',
#   'crypto',
#   'company',
#   'celsius',
#   'years',
#   'ahead',
#   'of',
#   'bankruptcy',
#   'https://t.co/5qdrafvnts'],
#  ['$', 'ormp', '7', 'to', '10.50', '👍', 'https://t.co/xvzt0kasd2'],
#  ['metawin',
#   'launches',
#   'moonbirds',
#   'tournament',
#   'with',
#   '26eth',
#   'nft',
#   'prize',
#   'https://t.co/w9zuwnkfap',
#   'https://t.co/koz2g4rput'],
#  ['commodities', 'getting', 'crushed', 'this', 'morning'],
#  ['tigo',
#   'energy',
#   'introduces',
#   'solar',
#   'rapid',
#   'shutdown',
#   'with',
#   'pure',
#   'signal',
#   'technology',
#   'https://t.co/zuzmm86iih',
#   'https://t.co/70jcebiuh6'],
#  ['a',
#   'large',
#   'majority',
#   'of',
#   'economists',
#   'see',
#   'the',
#   'bank',
#   'of',
#   'korea',
#   'raising',
#   'its',
#   'benchmark',
#   'interest',
#   'rate',
#   'by',
#   'a',
#   'half-percentage-point',
#   'on',
#   'wednesday',
#   ',',
#   'doubling',
#   'the',
#   'pace',
#   'of',
#   'its',
#   'policy',
#   'tightening',
#   'https://t.co/w8bestd00u'],
#  ['us',
#   'treasury',
#   'yields',
#   'have',
#   'risen',
#   'rapidly',
#   'this',
#   'year',
#   ',',
#   'but',
#   'billionaire',
#   'investor',
#   'leon',
#   'cooperman',
#   'thinks',
#   'they',
#   '’',
#   're',
#   'still',
#   'too',
#   'low',
#   'and',
#   'said',
#   'he',
#   '’',
#   'd',
#   'choose',
#   'stocks',
#   'over',
#   'bonds',
#   'https://t.co/leguhmzbou'],
#  ['euro-area',
#   'consumer',
#   'confidence',
#   'drops',
#   'to',
#   'its',
#   'lowest',
#   'level',
#   'on',
#   'record',
#   'as',
#   'households',
#   'brace',
#   'for',
#   'a',
#   'possible',
#   'recession',
#   'https://t.co/3fbvj8grdq'],
#  ['$',
#   'omc',
#   '-',
#   'omnicom',
#   'group',
#   'inc',
#   '.',
#   '(',
#   'omc',
#   ')',
#   'ceo',
#   'john',
#   'wren',
#   'on',
#   'q2',
#   '2022',
#   'results',
#   '-',
#   'earnings',
#   'call',
#   'transcript',
#   '.',
#   'https://t.co/opq1a8qvbs',
#   '#trading',
#   '#stockmarket',
#   '#stocks'],
#  ['10',
#   ')',
#   'wage',
#   'gain',
#   'distribution',
#   'wage',
#   'gains',
#   'for',
#   'lower-paid',
#   'workers',
#   'are',
#   'far',
#   'outstripping',
#   'those',
#   'of',
#   'higher',
#   'earnings',
#   '.',
#   'this',
#   'is',
#   'very',
#   'different',
#   'from',
#   'the',
#   'post',
#   '-',
#   '2008',
#   'environment',
#   'https://t.co/qvy9w1vpe4',
#   'https://t.co/ybgodmvop8'],
#  ['fortive',
#   'schedules',
#   'second',
#   'quarter',
#   '2022',
#   'earnings',
#   'conference',
#   'call',
#   'https://t.co/bi5zv4kkxp'],
#  ['samsung',
#   'electronics',
#   'develops',
#   'second-generation',
#   'smartssd',
#   'computational',
#   'storage',
#   'drive',
#   'with',
#   'upgraded',
#   'processing',
#   'functionality',
#   'https://t.co/yk6eus4qhs',
#   'https://t.co/wsmhneb3be'],
#  ['the',
#   'federal',
#   'minimum',
#   'wage',
#   "hasn't",
#   'gone',
#   'up',
#   'in',
#   '12',
#   'years',
#   '—',
#   'and',
#   'is',
#   'at',
#   'its',
#   'lowest',
#   'value',
#   'since',
#   '1956',
#   '(',
#   'via',
#   '@cnbcmakeit',
#   ')',
#   'https://t.co/i3nslxvvlg'],
#  ['weekend',
#   'news',
#   ':',
#   'fed',
#   'officials',
#   'preparing',
#   'to',
#   'lift',
#   'interest',
#   'rates',
#   'by',
#   'another',
#   '0.75',
#   'percentage',
#   'point',
#   '-',
#   'wsj',
#   'https://t.co/iuznhicyzp'],
#  ['terry',
#   'mccrann',
#   ':',
#   'lowest',
#   'australian',
#   'jobless',
#   'rate',
#   'in',
#   'nearly',
#   '50',
#   'years',
#   'locks',
#   'in',
#   '50bps',
#   'hike',
#   'from',
#   'rba',
#   'next',
#   'month',
#   '–',
#   'the',
#   'australian',
#   'https://t.co/g3rnpmcel1'],
#  ['$',
#   'osis',
#   '-',
#   'osi',
#   'systems',
#   'receives',
#   '$',
#   '6m',
#   'order',
#   'for',
#   'cargo',
#   'and',
#   'vehicle',
#   'inspection',
#   'systems',
#   'https://t.co/48r9dnuwwr'],
#  ['transparent',
#   'pv',
#   'windows',
#   'demonstrate',
#   'energy-efficiency',
#   'performance',
#   'in',
#   'next',
#   'energy',
#   'building',
#   'technology',
#   'project',
#   'at',
#   'nrel',
#   'https://t.co/jtt7nwg5jo',
#   'https://t.co/23upk9t4j0'],
#  ['joe',
#   'biden',
#   'has',
#   'put',
#   'together',
#   'an',
#   'effective',
#   'series',
#   'of',
#   'policies',
#   'to',
#   'contain',
#   "china's",
#   'ambitions',
#   ',',
#   'says',
#   'minxin',
#   'pei',
#   ',',
#   'but',
#   'his',
#   'own',
#   'rhetoric',
#   'is',
#   'undercutting',
#   'the',
#   'effort',
#   'https://t.co/rbgcsk2ija'],
#  ['$',
#   'omc',
#   '-',
#   'omnicom',
#   'group',
#   'inc',
#   '.',
#   '2022',
#   'q2',
#   '-',
#   'results',
#   '-',
#   'earnings',
#   'call',
#   'presentation',
#   '.',
#   'https://t.co/pckpwugldq',
#   '#stockmarket',
#   '#economy',
#   '#business'],
#  ['spicejet',
#   ',',
#   'the',
#   'indian',
#   'airline',
#   'already',
#   'under',
#   'scrutiny',
#   'from',
#   'regulators',
#   'in',
#   'the',
#   'country',
#   ',',
#   'had',
#   'another',
#   'technical',
#   'issue',
#   'after',
#   'a',
#   'flight',
#   'to',
#   'dubai',
#   ',',
#   'sources',
#   'say',
#   'https://t.co/cebx8yupqd'],
#  ['millennium',
#   'partners',
#   ',',
#   'l',
#   '.',
#   'p',
#   '.',
#   'uk',
#   'regulatory',
#   'announcement',
#   ':',
#   'form',
#   '8.3',
#   '-',
#   'homeserve',
#   'plc',
#   'https://t.co/wedm9deo27',
#   'https://t.co/h8rd7besxd'],
#  ['from',
#   'breakingviews',
#   '-',
#   'tesla',
#   'investors',
#   'bet',
#   'on',
#   'recovery',
#   'and',
#   'fantasy',
#   'https://t.co/a3pz1dreki'],
#  ['$',
#   'gwre',
#   '-',
#   'guidewire',
#   ':',
#   'expensively',
#   'valued',
#   'for',
#   'company',
#   'without',
#   'strong',
#   'competitive',
#   'offering',
#   '.',
#   'https://t.co/fqmugchxbt',
#   '#stocks',
#   '#business',
#   '#economy'],
#  ['china',
#   '’',
#   's',
#   'state-owned',
#   'chinatex',
#   'and',
#   'cofco',
#   'resources',
#   'agreed',
#   'to',
#   'pay',
#   '$',
#   '3.3',
#   'million',
#   'in',
#   'us',
#   'fines',
#   'issued',
#   'for',
#   'working',
#   'together',
#   'in',
#   '2020',
#   'to',
#   'evade',
#   'position',
#   'limits',
#   'in',
#   'cotton',
#   'futures',
#   'https://t.co/qgccoypxpo'],
#  ['groupe',
#   'touchette',
#   'strikes',
#   'a',
#   'deal',
#   'to',
#   'acquire',
#   'american',
#   'tire',
#   'distributors',
#   '’',
#   'assets',
#   'in',
#   'canada',
#   ',',
#   'a',
#   'move',
#   'that',
#   'may',
#   'roughly',
#   'double',
#   'its',
#   'annual',
#   'sales',
#   'https://t.co/lagevlqjk6'],
#  ['june',
#   'home',
#   'sales',
#   'fall',
#   '5.4',
#   '%',
#   'from',
#   'may',
#   ',',
#   'as',
#   'prices',
#   'set',
#   'yet',
#   'another',
#   'record',
#   'https://t.co/kns1aemd6z'],
#  ['$',
#   'is',
#   '(',
#   '+65.0',
#   '%',
#   'pre',
#   ')',
#   '$',
#   'u',
#   '(',
#   '-7.7',
#   '%',
#   'pre',
#   ')',
#   'unity',
#   'announces',
#   'merger',
#   'agreement',
#   'with',
#   'ironsource',
#   '-',
#   'bw',
#   'https://t.co/eihs2a2ww9'],
#  ['longtime',
#   'trump',
#   'adviser',
#   'steve',
#   'bannon',
#   'failed',
#   'once',
#   'more',
#   'to',
#   'persuade',
#   'a',
#   'judge',
#   'to',
#   'delay',
#   'his',
#   'criminal',
#   'contempt',
#   'trial',
#   'over',
#   'refusing',
#   'to',
#   'cooperate',
#   'with',
#   'the',
#   'house',
#   'panel',
#   'investigating',
#   'the',
#   'us',
#   'capitol',
#   'riot',
#   'https://t.co/ji8iiukl52'],
#  ['$',
#   'cmg',
#   '$',
#   'sg',
#   '$',
#   'yum',
#   '-',
#   'optimism',
#   'abounds',
#   'on',
#   'restaurant',
#   'stocks',
#   'amid',
#   'lighter',
#   'inflation',
#   'impact',
#   ',',
#   'looser',
#   'labor',
#   'market',
#   'https://t.co/moc0gjjnbt'],
#  ['eu',
#   'chief',
#   'diplomat',
#   'josep',
#   'borrell',
#   'hopes',
#   'for',
#   'ukraine',
#   'grain',
#   'deal',
#   '‘',
#   'this',
#   'week',
#   '’',
#   'https://t.co/gbdq5gljav'],
#  ['celsius',
#   'network',
#   'has',
#   'filed',
#   'for',
#   'chapter',
#   '11',
#   'bankruptcy',
#   ',',
#   'becoming',
#   'the',
#   'latest',
#   'casualty',
#   'of',
#   "'",
#   'crypto',
#   'winter',
#   "'",
#   'https://t.co/nimsgqxa7u'],
#  ['expectations',
#   'for',
#   'us',
#   'inflation',
#   'three',
#   'years',
#   'ahead',
#   'fell',
#   'to',
#   '3.6',
#   '%',
#   'in',
#   'june',
#   'from',
#   '3.9',
#   '%',
#   'a',
#   'month',
#   'earlier',
#   ',',
#   'the',
#   'biggest',
#   'drop',
#   'since',
#   'january',
#   ',',
#   'according',
#   'to',
#   'the',
#   'latest',
#   'survey',
#   'by',
#   'the',
#   'new',
#   'york',
#   'fed',
#   'https://t.co/60xojhbxjo'],
#  ['$',
#   'tblt',
#   '$',
#   'mltx',
#   '$',
#   'vedu',
#   '-',
#   'life',
#   ',',
#   'tblt',
#   'and',
#   'xtlb',
#   'among',
#   'pre',
#   'market',
#   'gainers',
#   'https://t.co/rafkmdffri'],
#  ['deliveroo',
#   'cuts',
#   '2022',
#   'gross',
#   'transaction',
#   'value',
#   'growth',
#   'views',
#   'https://t.co/vm1ylrtzfg'],
#  ['with',
#   'bold',
#   'pay',
#   'requirements',
#   ',',
#   'indecisiveness',
#   'and',
#   'disappearing',
#   'acts',
#   ',',
#   'young',
#   'job',
#   'seekers',
#   'are',
#   'making',
#   'recruiters',
#   "'",
#   'jobs',
#   'harder',
#   'https://t.co/zcyjhsr4a4'],
#  ['white',
#   'house',
#   'economic',
#   'adviser',
#   'boushey',
#   '-',
#   'congress',
#   'can',
#   'do',
#   'its',
#   'part',
#   'on',
#   'us',
#   'inflation',
#   'fight'],
#  ['as',
#   'the',
#   'u',
#   '.',
#   's',
#   '.',
#   'annualized',
#   'inflation',
#   'rate',
#   'hit',
#   'a',
#   '41',
#   '-',
#   'year',
#   'record',
#   'of',
#   '9.1',
#   '%',
#   ',',
#   'social',
#   'security',
#   'recipients',
#   'may',
#   'see',
#   'cost-of-living',
#   'adjustments',
#   'to',
#   'their',
#   'checks',
#   'next',
#   'year',
#   'like',
#   'never',
#   'before',
#   '.',
#   'https://t.co/ne0j4mrikn'],
#  ['medallia',
#   'approved',
#   'as',
#   'authorized',
#   'vendor',
#   'to',
#   'administer',
#   'cahps',
#   'for',
#   'mips',
#   'survey',
#   'https://t.co/1rusjdwr2n',
#   'https://t.co/xapmx4kiyc'],
#  ['morgan',
#   'stanley',
#   'names',
#   'its',
#   'top',
#   'stocks',
#   'in',
#   'a',
#   '‘',
#   'safe',
#   'haven',
#   '’',
#   'tech',
#   'sector',
#   '—',
#   'giving',
#   'one',
#   'upside',
#   'of',
#   '60',
#   '%',
#   'https://t.co/idwpetaifr'],
#  ['$',
#   'lulu',
#   '-',
#   'lululemon',
#   'athletica',
#   ':',
#   'getting',
#   'in',
#   'shape',
#   '.',
#   'https://t.co/zodoexx9qi',
#   '#markets',
#   '#investing',
#   '#stockmarket'],
#  ['cathie',
#   'wood',
#   '’',
#   's',
#   'ark',
#   'investment',
#   'management',
#   'to',
#   'close',
#   'transparency',
#   'etf',
#   ',',
#   'ark',
#   '’',
#   's',
#   'first',
#   'fund',
#   'closure',
#   'since',
#   'wood',
#   'launched',
#   'her',
#   'firm',
#   'in',
#   '2014',
#   '.',
#   'https://t.co/bdhq3wcddj'],
#  ['$',
#   'ipg',
#   '-',
#   'interpublic',
#   'group',
#   'of',
#   'companies',
#   'non-gaap',
#   'eps',
#   'of',
#   '$',
#   '0.63',
#   'beats',
#   'by',
#   '$',
#   '0.05',
#   ',',
#   'revenue',
#   'of',
#   '$',
#   '2.38',
#   'b',
#   'beats',
#   'by',
#   '$',
#   '50m',
#   'https://t.co/7qwgmggs4h'],
#  ['$',
#   'siga',
#   ':',
#   'siga',
#   'technologies',
#   'announces',
#   'approximately',
#   '$',
#   '28',
#   'mln',
#   'of',
#   'procurement',
#   'orders',
#   'for',
#   'oral',
#   'tpoxx',
#   'https://t.co/9pn2mw8dki'],
#  ['stride',
#   '$',
#   'lrn',
#   'unusual',
#   'buy',
#   '1000',
#   'august',
#   '$',
#   '43',
#   '/',
#   '$',
#   '48',
#   'call',
#   'spreads',
#   ',',
#   'very',
#   'impressive',
#   'chart',
#   '&',
#   'valuation'],
#  ['$',
#   'ibm',
#   '$',
#   'kd',
#   '-',
#   'ibm',
#   'slips',
#   'even',
#   'as',
#   'q2',
#   'earnings',
#   'top',
#   'expectations',
#   ',',
#   'aided',
#   'by',
#   'cloud',
#   'https://t.co/jgflit2raz'],
#  ['london',
#   'will',
#   'be',
#   'hotter',
#   'than',
#   'the',
#   'caribbean',
#   'and',
#   'the',
#   'western',
#   'sahara',
#   'with',
#   'temperatures',
#   'getting',
#   'up',
#   'to',
#   'at',
#   'least',
#   '38',
#   'degrees',
#   'celsius',
#   'https://t.co/9e9bxmhps6'],
#  ['thailand',
#   'faces',
#   'a',
#   'shortage',
#   'of',
#   'about',
#   '500,000',
#   'foreign',
#   'workers',
#   'in',
#   'its',
#   'manufacturing',
#   'and',
#   'services',
#   'sectors',
#   'to',
#   'support',
#   'an',
#   'economic',
#   'recovery',
#   'from',
#   'the',
#   'pandemic',
#   'after',
#   'the',
#   'government',
#   'lifted',
#   'almost',
#   'all',
#   'covid-related',
#   'travel',
#   'and',
#   'business',
#   'restrictions',
#   'https://t.co/a3c56pchbv'],
#  ['midstream',
#   'weekly',
#   'recap',
#   ':',
#   'midstream',
#   'hangs',
#   'tough',
#   'while',
#   'the',
#   'energy',
#   'sector',
#   'declines',
#   '.',
#   'https://t.co/rmnk3j2pbw',
#   '#markets',
#   '#investing',
#   '#business'],
#  ['$',
#   'cntg',
#   '-',
#   'centogene',
#   'gaap',
#   'eps',
#   'of',
#   '-',
#   '€',
#   '0.28',
#   ',',
#   'revenue',
#   'of',
#   '€',
#   '10.32',
#   'm',
#   'https://t.co/t2b8kcmjcn'],
#  ['bulgaria',
#   '’',
#   's',
#   'president',
#   'will',
#   'give',
#   'the',
#   'socialist',
#   'party',
#   'a',
#   'mandate',
#   'to',
#   'form',
#   'a',
#   'new',
#   'government',
#   'in',
#   'a',
#   'last-ditch',
#   'bid',
#   'to',
#   'avoid',
#   'triggering',
#   'the',
#   'fourth',
#   'election',
#   'in',
#   'less',
#   'than',
#   'two',
#   'years',
#   'https://t.co/auwu0pxzuz'],
#  ['president',
#   'biden',
#   'bumped',
#   'fists',
#   'with',
#   'saudi',
#   'arabia',
#   '’',
#   's',
#   'crown',
#   'prince',
#   'mohammed',
#   'when',
#   'the',
#   'two',
#   'men',
#   'met',
#   'for',
#   'the',
#   'first',
#   'time',
#   'in',
#   'jeddah',
#   'on',
#   'friday',
#   ',',
#   'effectively',
#   'putting',
#   'an',
#   'end',
#   'to',
#   'his',
#   'efforts',
#   'to',
#   'shun',
#   'the',
#   'saudi',
#   'leader',
#   'https://t.co/tsjkuvhxcq'],
#  ['$',
#   'wgo',
#   '$',
#   'lcii',
#   '$',
#   'tho',
#   '-',
#   'recreational',
#   'vehicles',
#   'retail',
#   'registrations',
#   'drop',
#   'in',
#   'may',
#   'https://t.co/cpech8ykgx'],
#  ['📉',
#   'twitter',
#   'stock',
#   'was',
#   'trading',
#   '5',
#   '%',
#   'below',
#   'a',
#   'weighted-average',
#   'price',
#   'at',
#   'which',
#   'elon',
#   'musk',
#   'bought',
#   'his',
#   '73,115',
#   ',',
#   '038',
#   '$',
#   'twtr',
#   'shares',
#   '.',
#   'here',
#   '’',
#   's',
#   'how',
#   'much',
#   'musk',
#   'is',
#   'losing',
#   'on',
#   'his',
#   'stake',
#   '👉',
#   'https://t.co/tfxwnqohdf',
#   'https://t.co/gg6kapvx2d'],
#  ['you',
#   'can',
#   'ask',
#   'amazon',
#   'to',
#   'not',
#   'use',
#   'plastic',
#   'packaging',
#   'materials',
#   'for',
#   'your',
#   'orders',
#   '.',
#   'make',
#   'the',
#   'request',
#   'via',
#   'email',
#   'or',
#   'use',
#   'the',
#   'chat',
#   'option',
#   'and',
#   'request',
#   'that',
#   'future',
#   'orders',
#   'be',
#   'plastic-free',
#   'with',
#   'minimal',
#   'packaging',
#   '.',
#   'this',
#   'information',
#   'will',
#   'be',
#   'saved',
#   'to',
#   'your',
#   'account',
#   '.',
#   'https://t.co/owopd8bprk'],
#  ['$',
#   'rtx',
#   '$',
#   'lmt',
#   '$',
#   'noc',
#   '-',
#   'raytheon',
#   'ceo',
#   ':',
#   'supply',
#   'chain',
#   'issues',
#   'and',
#   'labor',
#   'shortages',
#   'could',
#   'last',
#   'into',
#   '2024',
#   'https://t.co/icbxtrqvo0'],
#  ['molina',
#   'healthcare',
#   'to',
#   'acquire',
#   'my',
#   'choice',
#   'wisconsin',
#   'https://t.co/lfyfpq9mxo',
#   'https://t.co/iwfs2kuzfz'],
#  ['$',
#   'bbw',
#   '-',
#   "build-a-bear's",
#   'stuffed',
#   'fundamentals',
#   'with',
#   'potential',
#   'boosts',
#   'in',
#   "children's",
#   'population',
#   '.',
#   'https://t.co/2iwjhqmuvw',
#   '#markets',
#   '#finance',
#   '#economy'],
#  ['bionic',
#   'clothing',
#   'innovator',
#   'cionic',
#   'announces',
#   'collaboration',
#   'with',
#   'yves',
#   'behar',
#   '’',
#   's',
#   'fuseproject',
#   'https://t.co/rlxy8zatiq',
#   'https://t.co/5w7lxs9rv9'],
#  ['draghi',
#   'demands',
#   'italian',
#   'unity',
#   'as',
#   'price',
#   'for',
#   'staying',
#   'on',
#   'as',
#   'pm',
#   '-',
#   'reuters',
#   'https://t.co/6hlhnvhnzs'],
#  ['$',
#   'kscp',
#   '-',
#   'knightscope',
#   'signs',
#   'contract',
#   'with',
#   'a',
#   'growing',
#   'multifamily',
#   'real',
#   'estate',
# ...
#   '#trading',
#   '#stockmarket'],
#  ['eu',
#   'to',
#   'raise',
#   'inflation',
#   'forecasts',
#   'as',
#   'officials',
#   'prepare',
#   'for',
#   'a',
#   'permanent',
#   'cut',
#   'to',
#   'russian',
#   'gas',
#   'https://t.co/widdvxyern'],
#  ['hyosung',
#   'america',
#   'adds',
#   'premier',
#   'cash-to-cryptocurrency',
#   'provider',
#   'digitalmint',
#   'to',
#   'its',
#   'forthcoming',
#   'app',
#   'store',
#   'https://t.co/nxnyj12a9y',
#   'https://t.co/fxesry01km'],
#  ['$',
#   'scanx',
#   ':',
#   'large',
#   'cap',
#   'notable',
#   'movers',
#   'of',
#   'interest',
#   'https://t.co/deqnwhvlcb'],
#  ["modi's",
#   'promise',
#   'to',
#   'ban',
#   'plastic',
#   'straws',
#   'this',
#   'month',
#   'put',
#   'india',
#   'in',
#   'the',
#   'lead',
#   'in',
#   'the',
#   'region',
#   'for',
#   'curbing',
#   'pollution',
#   '.',
#   'but',
#   'many',
#   'beverage',
#   'makers',
#   "aren't",
#   'ready',
#   '.',
#   'https://t.co/mbjscqj9g7'],
#  ['$',
#   'lin',
#   '-',
#   'linde',
#   'to',
#   'supply',
#   'high-purity',
#   'industrial',
#   'gases',
#   'to',
#   'pt',
#   'freeport',
#   'indonesia',
#   'https://t.co/5tpk9utao5'],
#  ['vietjet',
#   'aviation',
#   'confirmed',
#   'a',
#   'deal',
#   'for',
#   '200',
#   'boeing',
#   '737',
#   'max',
#   'jets',
#   ',',
#   'giving',
#   'the',
#   'us',
#   'planemaker',
#   'another',
#   'boost',
#   'at',
#   'one',
#   'of',
#   'the',
#   'industry',
#   '’',
#   's',
#   'biggest',
#   'events',
#   'https://t.co/3yxn8105d3'],
#  ['biden',
#   'meets',
#   'with',
#   'saudi',
#   'arabia',
#   '’',
#   's',
#   'mohammed',
#   'bin',
#   'salman',
#   'for',
#   'the',
#   'first',
#   'time',
#   'in',
#   'jeddah',
#   ',',
#   'effectively',
#   'putting',
#   'an',
#   'end',
#   'to',
#   'the',
#   'us',
#   "leader's",
#   'efforts',
#   'to',
#   'shun',
#   'the',
#   'crown',
#   'prince',
#   'https://t.co/ylo2veq3gg',
#   'https://t.co/rpyiatid44'],
#  ['5',
#   ')',
#   'consumer',
#   'strength',
#   'consumer',
#   'confidence',
#   'is',
#   'in',
#   'terrible',
#   'shape',
#   'today',
#   '.',
#   'however',
#   ',',
#   'hard',
#   'measures',
#   'of',
#   'consumer',
#   'health',
#   'are',
#   'far',
#   'better',
#   'than',
#   'basically',
#   'any',
#   'period',
#   'during',
#   'the',
#   'last',
#   'big',
#   'downturn',
#   'https://t.co/qvy9w1vpe4',
#   'https://t.co/5mhxvw3b6p'],
#  ['reply',
#   'receives',
#   '2022',
#   'sap',
#   '®',
#   'pinnacle',
#   'award',
#   'in',
#   'the',
#   'customer',
#   'excellence',
#   'category',
#   'https://t.co/y2qmh0yyap',
#   'https://t.co/wngtiz4k8w'],
#  ['$',
#   'vrtx',
#   '-',
#   'vertex',
#   'announces',
#   'viacyte',
#   'acquisition',
#   'to',
#   'expand',
#   'diabetes',
#   'pipeline',
#   'https://t.co/nuquazjw6d'],
#  ['$',
#   'leo',
#   '-',
#   'bny',
#   'mellon',
#   'strategic',
#   'municipals',
#   'goes',
#   'ex',
#   'dividend',
#   'tomorrow',
#   'https://t.co/iowcec49ik'],
#  ['$',
#   'jbl',
#   '-',
#   "jabil's",
#   'unique',
#   'expertise',
#   'and',
#   'secular',
#   'tailwinds',
#   'drive',
#   'profit',
#   'growth',
#   '.',
#   'https://t.co/hfogxnf6r2',
#   '#stocks',
#   '#markets',
#   '#trading'],
#  ['choppy',
#   'start',
#   'to',
#   'the',
#   'day',
#   'with',
#   'mixed',
#   'buying',
#   'interest',
#   '$',
#   'spy',
#   '$',
#   'qqq',
#   '$',
#   'dia',
#   '$',
#   'spx',
#   '$',
#   'compq',
#   '$',
#   'djia',
#   '$',
#   'xle',
#   '$',
#   'xlv',
#   '$',
#   'xlk',
#   '$',
#   'xlf',
#   '$',
#   'xlb',
#   '$',
#   'xli',
#   '$',
#   'mgk',
#   '$',
#   'rsp',
#   '$',
#   'cl_f',
#   '$',
#   'msft',
#   '$',
#   'amzn',
#   '$',
#   'rut',
#   '$',
#   'soxx',
#   'https://t.co/lzemmlqjhi',
#   '#economy',
#   '#stockmarket'],
#  ['cary',
#   'street',
#   'partners',
#   'grows',
#   'in',
#   'hampton',
#   'roads',
#   'https://t.co/dks6c6uxiq',
#   'https://t.co/cvfpp2x1qz'],
#  ['south',
#   'korea',
#   '’',
#   's',
#   'unemployment',
#   'rate',
#   'remained',
#   'below',
#   '3',
#   '%',
#   'in',
#   'june',
#   ',',
#   'suggesting',
#   'the',
#   'labor',
#   'market',
#   'is',
#   'largely',
#   'holding',
#   'up',
#   'for',
#   'now',
#   'in',
#   'the',
#   'face',
#   'of',
#   'rising',
#   'inflation',
#   'and',
#   'interest',
#   'rates',
#   'https://t.co/243idecgxf'],
#  ['$', 'sabr', '$', 'voxx', '$', 'iti'],
#  ['good',
#   'times',
#   'restaurants',
#   'reports',
#   'third',
#   'fiscal',
#   'quarter',
#   'same',
#   'store',
#   'sales',
#   'https://t.co/pq813rhvl7',
#   'https://t.co/u27pxagkui'],
#  ['wow',
#   ',',
#   'if',
#   'you',
#   'showed',
#   'me',
#   'that',
#   '$',
#   'nflx',
#   'report',
#   'ahead',
#   'of',
#   'time',
#   ',',
#   'would',
#   'think',
#   'it',
#   'would',
#   'be',
#   'down',
#   'sharply',
#   'if',
#   'does',
#   'not',
#   'fade',
#   ',',
#   'truly',
#   'showing',
#   'how',
#   'washed',
#   'out',
#   'sentiment',
#   'is',
#   ',',
#   'low-bar',
#   'q3',
#   'guided',
#   'eps',
#   'of',
#   '$',
#   '2.14',
#   'vs',
#   '.',
#   '$',
#   '2.76',
#   'consensus',
#   ';',
#   'revenues',
#   'of',
#   '$',
#   '7.838',
#   'b',
#   'vs',
#   '.',
#   '$',
#   '8.1',
#   'b',
#   'and',
#   'major',
#   'margin',
#   'cut'],
#  ['it',
#   'may',
#   'seem',
#   'like',
#   'an',
#   'oxymoron',
#   ',',
#   'but',
#   'the',
#   'single-stock',
#   'etf',
#   'is',
#   'already',
#   'a',
#   'thing',
#   'in',
#   'europe',
#   'https://t.co/heisqq2ki5'],
#  ['investor',
#   'alert',
#   ':',
#   'law',
#   'offices',
#   'of',
#   'howard',
#   'g',
#   '.',
#   'smith',
#   'announces',
#   'investigation',
#   'of',
#   'hannon',
#   'armstrong',
#   'sustainable',
#   'infrastructure',
#   'capital',
#   ',',
#   'inc',
#   '.',
#   '(',
#   'hasi',
#   ')',
#   'on',
#   'behalf',
#   'of',
#   'investors',
#   'https://t.co/mqcmh461df',
#   'https://t.co/gdpvnlpfok'],
#  ['64',
#   '%',
#   'of',
#   'consumers',
#   'plan',
#   'to',
#   'shop',
#   'during',
#   'amazon',
#   'prime',
#   'day',
#   ',',
#   'particularly',
#   'for',
#   'household',
#   'items',
#   ',',
#   'according',
#   'to',
#   'nielseniq',
#   '.',
#   'many',
#   'will',
#   'also',
#   'be',
#   'looking',
#   'for',
#   'deals',
#   'on',
#   'groceries',
#   '.',
#   'https://t.co/chxrttnhxk'],
#  ['the',
#   'fed',
#   'is',
#   'winning',
#   'against',
#   'inflation',
#   'despite',
#   'red-hot',
#   'june',
#   'cpi',
#   'number',
#   ',',
#   'jim',
#   'cramer',
#   'says',
#   'https://t.co/qsba7ma8iq'],
#  ['"',
#   'many',
#   'of',
#   'his',
#   'supporters',
#   "'",
#   'lives',
#   'will',
#   'never',
#   'be',
#   'the',
#   'same',
#   '.',
#   '"',
#   'rep',
#   '.',
#   'murphy',
#   'talked',
#   'about',
#   "trump's",
#   'jan',
#   '.',
#   '6',
#   'speech',
#   'during',
#   'the',
#   'hearing',
#   ',',
#   'saying',
#   'it',
#   'was',
#   'built',
#   'on',
#   'a',
#   'foundation',
#   'of',
#   'lies',
#   'and',
#   'that',
#   'as',
#   'a',
#   'result',
#   ',',
#   'people',
#   'died',
#   'https://t.co/l7xagt74yc',
#   'https://t.co/vmqkhl9age'],
#  ['from',
#   'breakingviews',
#   '-',
#   'aho',
#   '’',
#   's',
#   'bounceback',
#   'proves',
#   'scandal',
#   '’',
#   's',
#   'short',
#   'shelf',
#   'life',
#   'https://t.co/ttai8fscoq'],
#  ['twitter',
#   'suffered',
#   'a',
#   'major',
#   'global',
#   'outage',
#   'this',
#   'morning',
#   'https://t.co/pvpbsfbypp'],
#  ['the',
#   'dow',
#   'is',
#   'close',
#   'to',
#   'flat',
#   'as',
#   'more',
#   'earnings',
#   'reports',
#   'roll',
#   'in',
#   'that',
#   'are',
#   'being',
#   'interpreted',
#   'by',
#   'investors',
#   'as',
#   'mixed',
#   'signals',
#   'about',
#   'the',
#   'economy',
#   'https://t.co/9nfb0frfqp'],
#  ['in',
#   'china',
#   ',',
#   'the',
#   'government',
#   'usually',
#   'gets',
#   'what',
#   'it',
#   'wants',
#   '.',
#   "that's",
#   'what',
#   'made',
#   "beijing's",
#   'vaccine',
#   'mandate',
#   'reversal',
#   'so',
#   'interesting',
#   'https://t.co/hq52ewxvjk'],
#  ['toronto',
#   'stock',
#   'index',
#   '.',
#   'gsptse',
#   'unofficially',
#   'closes',
#   'down',
#   '286.13',
#   'points',
#   ',',
#   'or',
#   '1.54',
#   '%',
#   ',',
#   'at',
#   '18,329',
#   '.',
#   '06'],
#  ['western',
#   'union',
#   'introduces',
#   'enhanced',
#   'cross-border',
#   'remittance',
#   'experience',
#   'in',
#   'chile',
#   'https://t.co/twm2eeumdo',
#   'https://t.co/hbvpgizg0n'],
#  ['uk',
#   'house',
#   'prices',
#   'rise',
#   'at',
#   'fastest',
#   'rate',
#   'in',
#   '18',
#   'years',
#   'https://t.co/ksjzsf8zoe'],
#  ['china',
#   '’',
#   's',
#   'economic',
#   'growth',
#   'will',
#   'likely',
#   'slip',
#   'below',
#   '4',
#   '%',
#   'this',
#   'year',
#   'as',
#   'the',
#   'nation',
#   '’',
#   's',
#   'covid',
#   'zero',
#   'policy',
#   ',',
#   'a',
#   'crisis',
#   'in',
#   'the',
#   'property',
#   'sector',
#   'and',
#   'a',
#   'darkening',
#   'global',
#   'outlook',
#   'continue',
#   'to',
#   'weigh',
#   'on',
#   'the',
#   'country',
#   'https://t.co/vty19m4u3f'],
#  ['hsbc',
#   'signs',
#   'agreement',
#   'to',
#   'sell',
#   'russia',
#   'business',
#   'to',
#   'expobank',
#   '-',
#   'rtrs'],
#  ['a',
#   'blistering',
#   'heatwave',
#   'in',
#   'europe',
#   'shows',
#   "what's",
#   'at',
#   'stake',
#   'for',
#   'the',
#   "region's",
#   'climate',
#   'ambitions',
#   'https://t.co/gvv54tga3h'],
#  ['a',
#   'blind',
#   'spot',
#   'is',
#   'building',
#   'up',
#   'in',
#   'the',
#   'uk',
#   'energy',
#   'market',
#   '.',
#   "it's",
#   'unclear',
#   'how',
#   'much',
#   'demand',
#   'for',
#   'aircon',
#   'will',
#   'increase',
#   'after',
#   'the',
#   'latest',
#   'heatwave',
#   'is',
#   'over',
#   'https://t.co/az1uze18f2'],
#  ['i',
#   '’',
#   've',
#   'been',
#   'defrauded',
#   '-',
#   'why',
#   'won',
#   '’',
#   't',
#   'my',
#   'bank',
#   'refund',
#   'me',
#   '?',
#   'https://t.co/m9crb7huc9'],
#  ['the',
#   'strategy',
#   'of',
#   'buying',
#   'bitcoin',
#   'at',
#   'the',
#   'close',
#   'of',
#   'us',
#   'equity',
#   'markets',
#   'and',
#   'selling',
#   'it',
#   'at',
#   'the',
#   'next',
#   'open',
#   'is',
#   'losing',
#   'some',
#   'of',
#   'its',
#   'attractiveness',
#   'https://t.co/nu7vwijuud'],
#  ['fed',
#   'could',
#   'weigh',
#   'historic',
#   '100',
#   'basis-point',
#   'hike',
#   'after',
#   'inflation',
#   'scorcher',
#   '-',
#   'bbg',
#   'https://t.co/qgd8u7ju1v'],
#  ['the',
#   'zloty',
#   '’',
#   's',
#   'recent',
#   'depreciation',
#   'isn',
#   '’',
#   't',
#   'enough',
#   'to',
#   'delay',
#   'inflation',
#   'peak',
#   'beyond',
#   'the',
#   'third',
#   'quarter',
#   ',',
#   'says',
#   'governor',
#   'adam',
#   'glapinski',
#   'https://t.co/fx8h1dnbyk'],
#  ['agilent',
#   'to',
#   'announce',
#   'third-quarter',
#   'fiscal',
#   'year',
#   '2022',
#   'financial',
#   'results',
#   'august',
#   '16',
#   'https://t.co/qdth2msvgw',
#   'https://t.co/w3kak1v0pu'],
#  ['asian',
#   'stocks',
#   'look',
#   'set',
#   'for',
#   'a',
#   'wary',
#   'open',
#   'after',
#   'sizzling',
#   'us',
#   'inflation',
#   'data',
#   'buffeted',
#   'wall',
#   'street',
#   ',',
#   'hardening',
#   'bets',
#   'on',
#   'an',
#   'even',
#   'more',
#   'aggressive',
#   'fed',
#   'campaign',
#   'of',
#   'monetary',
#   'tightening',
#   'https://t.co/bfrus5uy3q'],
#  ['‘',
#   'the',
#   'return',
#   'of',
#   'cash',
#   '’',
#   ':',
#   'money',
#   'market',
#   'fund',
#   'sector',
#   'perks',
#   'up',
#   'on',
#   'rising',
#   'rates',
#   'https://t.co/zehs7ohgmd'],
#  ['+',
#   'initiations',
#   '7/14',
#   ':',
#   '$',
#   'adtn',
#   '$',
#   'ctva',
#   '$',
#   'krtx',
#   '$',
#   'mgni',
#   '$',
#   'mos',
#   '$',
#   'nfe',
#   '$',
#   'snx',
#   '$',
#   'ste',
#   '$',
#   'tsla',
#   '$',
#   'tvtx',
#   '.',
#   '-',
#   'initiations',
#   '7/14',
#   ':',
#   '$',
#   'avt',
#   '$',
#   'cf',
#   '$',
#   'ntr'],
#  ['$',
#   'hiti',
#   '(',
#   '-19.0',
#   '%',
#   'pre',
#   ')',
#   'high',
#   'tide',
#   'to',
#   'raise',
#   'c',
#   '$',
#   '10m',
#   'in',
#   'equity',
#   'offering',
#   '-',
#   'sa',
#   'https://t.co/5nypxrsnry'],
#  ['the',
#   'french',
#   'government',
#   'is',
#   'offering',
#   '12',
#   'euros',
#   'per',
#   'share',
#   'to',
#   'take',
#   'full',
#   'control',
#   'of',
#   'edf',
#   'in',
#   'a',
#   'nearly',
#   '$',
#   '10',
#   'billion',
#   'buyout',
#   'offer',
#   'that',
#   'gives',
#   'it',
#   'a',
#   'free',
#   'hand',
#   'to',
#   'run',
#   'the',
#   'group',
#   'as',
#   'it',
#   'contends',
#   'with',
#   'a',
#   'european',
#   'energy',
#   'crisis',
#   'https://t.co/shmafrx8gi'],
#  ['the',
#   'ptsd',
#   'from',
#   'q1',
#   '/',
#   'q2',
#   'out',
#   'there',
#   'is',
#   'real',
#   '...',
#   'stream',
#   'was',
#   'so',
#   'bearish',
#   'while',
#   'all',
#   'signs',
#   'been',
#   'there',
#   'of',
#   'money',
#   'being',
#   'put',
#   'back',
#   'to',
#   'work',
#   '$',
#   'qqq',
#   '+',
#   '7',
#   '%',
#   'in',
#   '2h22',
#   'already',
#   '...',
#   'following',
#   'prediction',
#   'that',
#   '2h',
#   'is',
#   'very',
#   'diff',
#   '.',
#   'than',
#   '1h',
#   'in',
#   '2022'],
#  ['mortgage',
#   'rates',
#   'edge',
#   'higher',
#   'this',
#   'week',
#   'https://t.co/stujeoaymf',
#   'by',
#   '@__gabriellacruz',
#   'https://t.co/gpaztrmfom'],
#  ['broad',
#   'participation',
#   'as',
#   'cumulative',
#   'tick',
#   'makes',
#   'fresh',
#   'highs',
#   'opening',
#   '90',
#   'minutes',
#   'trending',
#   'with',
#   'banks',
#   ',',
#   'transports',
#   ',',
#   'tech',
#   ',',
#   'retail',
#   ',',
#   'industrials',
#   ',',
#   'consumer',
#   'disc',
#   '.',
#   'all',
#   'up',
#   'over',
#   '1',
#   '%'],
#  ['morgan',
#   "stanley's",
#   'jonas',
#   'trims',
#   'price',
#   'target',
#   'for',
#   'tesla',
#   ',',
#   'citing',
#   'slowing',
#   'economy',
#   'https://t.co/xvfrertngr'],
#  ['apyx',
#   'medical',
#   'corporation',
#   'receives',
#   'fda',
#   '510',
#   '(',
#   'k',
#   ')',
#   'clearance',
#   'for',
#   'the',
#   'use',
#   'of',
#   'renuvion',
#   '®',
#   'to',
#   'improve',
#   'appearance',
#   'of',
#   'lax',
#   '(',
#   'loose',
#   ')',
#   'skin',
#   'https://t.co/nvha0wawsj',
#   'https://t.co/xf735hzp5j'],
#  ['beihai',
#   ',',
#   'a',
#   'seaside',
#   'tourist',
#   'city',
#   'in',
#   'southern',
#   'china',
#   '’',
#   's',
#   'guangxi',
#   'province',
#   ',',
#   'has',
#   'become',
#   'the',
#   'latest',
#   'covid',
#   'hotspot',
#   'https://t.co/w9gann1ed7'],
#  ['the',
#   's',
#   '&',
#   'p',
#   '500',
#   'suffered',
#   'its',
#   'fifth',
#   'consecutive',
#   'day',
#   'of',
#   'losses',
#   'as',
#   'earnings',
#   'season',
#   'kicked',
#   'off',
#   'with',
#   'the',
#   'first',
#   'reports',
#   'from',
#   'major',
#   'banks',
#   'https://t.co/4coiwdtz5e'],
#  ['2q22',
#   ':',
#   'alcoa',
#   'posts',
#   'strong',
#   'financial',
#   'results',
#   ',',
#   'provides',
#   'returns',
#   'to',
#   'stockholders',
#   'https://t.co/rd1lgsoilw',
#   'https://t.co/b7xrld43gd'],
#  ['$',
#   'usdc-usd',
#   '$',
#   'usb',
#   '$',
#   'si',
#   '-',
#   "circle's",
#   'reserve',
#   'assets',
#   'in',
#   'usdc',
#   "'",
#   'solely',
#   "'",
#   'backed',
#   'by',
#   'cash',
#   ',',
#   'short-term',
#   'treasuries',
#   'https://t.co/qylp7ld6zk'],
#  ['$',
#   'lstr',
#   '-',
#   'landstar',
#   'system',
#   'raises',
#   'dividend',
#   'by',
#   '20',
#   '%',
#   'to',
#   '$',
#   '0.30',
#   '/',
#   'share',
#   'https://t.co/a8yuvi6swj'],
#  ['$',
#   'azz',
#   '(',
#   '+4.6',
#   '%',
#   'pre',
#   ')',
#   'azz',
#   'inc',
#   '.',
#   'reports',
#   'results',
#   'for',
#   'first',
#   'quarter',
#   'of',
#   'fiscal',
#   'year',
#   '2023',
#   ';',
#   'generates',
#   'eps',
#   'of',
#   '$',
#   '0.96',
#   'and',
#   'adjusted',
#   'eps',
#   'of',
#   '$',
#   '1.40',
#   '-',
#   'prn',
#   'https://t.co/hj8q31q7ez'],
#  ['$',
#   'epr',
#   '-',
#   'epr',
#   'properties',
#   'declares',
#   '$',
#   '0.275',
#   'dividend',
#   'https://t.co/gq2cyg0qea'],
#  ['$',
#   'xm',
#   ':',
#   'qualtrics',
#   'misses',
#   'by',
#   '$',
#   '0.04',
#   ',',
#   'beats',
#   'on',
#   'revs',
#   ';',
#   'guides',
#   'q3',
#   'eps',
#   'below',
#   'consensus',
#   ',',
#   'revs',
#   'in-line',
#   ';',
#   'guides',
#   'fy22',
#   'eps',
#   'below',
#   '...',
#   'https://t.co/e0vopgltj4'],
#  ['european',
#   'fertilizer',
#   'giant',
#   'yara',
#   'international',
#   'says',
#   'the',
#   'energy',
#   'crisis',
#   'is',
#   'forcing',
#   'it',
#   'to',
#   'curb',
#   'output',
#   'and',
#   'warned',
#   'that',
#   'more',
#   'cuts',
#   'may',
#   'come',
#   'https://t.co/oqzw3azodr'],
#  ["apple's",
#   'near-term',
#   'future',
#   'looks',
#   'murky',
#   'as',
#   'consumer',
#   'spending',
#   'slows',
#   ',',
#   'bernstein',
#   'says',
#   'https://t.co/21t9lreta4'],
#  ['$',
#   'chwwf',
#   '-',
#   'chesswood',
#   'group',
#   'declares',
#   'cad',
#   '0.04',
#   'dividend',
#   'https://t.co/y6p78ldtuh'],
#  ['the',
#   'africa',
#   'cdc',
#   'has',
#   'been',
#   'given',
#   'authority',
#   'to',
#   'declare',
#   'public',
#   'health',
#   'emergencies',
#   'https://t.co/a1nq2e78eu'],
#  ['libyan',
#   'tribal',
#   'groups',
#   'agree',
#   'with',
#   'govt-appointed',
#   'noc',
#   'chief',
#   'to',
#   'reopen',
#   'oil',
#   'facilities',
#   ',',
#   'tribal',
#   'leader',
#   'says'],
#  ['ares',
#   'dynamic',
#   'credit',
#   'allocation',
#   'fund',
#   'declares',
#   'a',
#   'monthly',
#   'distribution',
#   'of',
#   '$',
#   '0.0975',
#   'per',
#   'share',
#   'https://t.co/ii7zm2rhjl',
#   'https://t.co/chny2xvn3t'],
#  ['canadian',
#   'bond',
#   'and',
#   'index',
#   'update',
#   '@mtlexchange',
#   'https://t.co/zs8wguhnh1'],
#  ['$',
#   'bac',
#   ':',
#   'bank',
#   'of',
#   'america',
#   ':',
#   'occ',
#   'assesses',
#   '$',
#   '125',
#   'mln',
#   'civil',
#   'money',
#   'penalty',
#   'against',
#   'bank',
#   'of',
#   'america',
#   ',',
#   'orders',
#   'restitution',
#   'for',
#   '...',
#   'https://t.co/m5rdxagsvd'],
#  ...]

# %%
# vector_size is the size of the "description" of numbers that each word has
# window is how many words around each word it looks at
# min_count is the minimum count words have to appear for them to be included
# workers is CPU threads (like in CNN)

from gensim.models import Word2Vec
Word_2_Vec_model = Word2Vec(sentences, vector_size = 100, window = 5, min_count = 2, workers = 4)
Word_2_Vec_model.wv['market']
# Out:
# array([-0.7435041 ,  0.3369793 ,  0.01310873,  0.32194504,  0.83976024,
#        -0.72339565,  0.52445555,  1.7122757 , -0.47170347, -0.75354034,
#        -0.08619314, -0.7840363 ,  0.1097462 , -0.24217422,  0.29970196,
#        -0.73802364,  0.25901827, -0.15547384, -0.06081613, -0.64018905,
#        -0.15364842,  0.29414248,  0.6422181 , -0.33100072, -0.01412233,
#         0.511995  , -0.45955336,  0.30057395, -0.92960507,  0.61727726,
#         0.7069179 , -0.2478343 , -0.19704394, -1.0004194 , -0.15829918,
#         0.5207405 ,  0.2978375 , -0.13940336, -0.39192295, -0.6298968 ,
#         0.25032344, -0.55573004, -0.274935  ,  0.333148  ,  0.55674136,
#        -0.241822  ,  0.25761712, -0.5153722 ,  0.5355474 , -0.0164644 ,
#         0.6952297 , -0.5959382 ,  0.18435556, -0.45186874, -0.48699197,
#         0.56586057,  0.21501319,  0.31458977, -0.12432434,  0.29972097,
#        -0.16350983,  0.01251933,  0.49007285, -0.13107885, -0.85317165,
#         0.5971322 ,  0.23539756,  0.6604556 , -0.77473384,  0.66300446,
#         0.27713078,  0.10622004,  0.90669674,  0.6749828 ,  0.42794138,
#         0.0023335 , -0.26592204, -0.3278574 , -0.5037378 ,  0.11772808,
#        -0.4430348 ,  0.28205633, -0.67957324,  0.34420115, -0.35334173,
#        -0.06485952,  0.5835991 ,  0.21809316,  0.41059613,  0.02875299,
#         1.1260198 ,  0.06286947,  0.12906569, -0.3224517 ,  1.1749691 ,
#         0.22453648,  0.49823013, -0.6751313 ,  0.20743348, -0.34290445],
#       dtype=float32)

# %%
my_word = "market"
count = Word_2_Vec_model.wv.get_vecattr(my_word, "count")
count

# this means that market appeared 548 times in my dataset!
# Out:
# np.int64(548)

# %%
# now that i have each word as a vector, i want to apply that to each of my words, and then take the average and save that as my "vector" for the entire tweet
X = []
for token_array in df["tokens"]:
    # for each tweet: 
    words_tokenized = [] # make a list
    for token in token_array: # for each word in the tweet
        if token in Word_2_Vec_model.wv: # if it's not rare enough and we managed to save it as an array
            words_tokenized.append(Word_2_Vec_model.wv[token]) # add it's token to the list
    if len(words_tokenized) == 0: # if my tweet is so rare that we managed actually no words to get in my model (seems impossible but just in case)
        X.append(np.zeros(100)) # this is just gonna be 0 for everything
    else:
        X.append(np.mean(words_tokenized, axis = 0)) # if it's not rare, and we were able to get at least one word saved into the model and into words_tokenized, take the average of all of the words and save that as the tweet's token
X
# Out:
# [array([-0.15790641,  0.39799747,  0.15869679,  0.05714073,  0.6099699 ,
#         -0.64989   ,  0.69576335,  1.5442752 , -0.09168743, -0.7823328 ,
#          0.08792872, -0.5017299 ,  0.10546329, -0.12013817, -0.01909365,
#         -0.36256197,  0.2503575 , -0.26250836,  0.02469015, -0.6759147 ,
#          0.14814205,  0.21148533,  0.38261262, -0.10906857,  0.25343972,
#          0.52308315,  0.32891503,  0.4988923 , -0.4667751 ,  0.45885238,
#         -0.251113  ,  0.14260526,  0.44561997,  0.12412509,  0.29136994,
#          0.11665705, -0.01670003,  0.00338425, -0.37602127, -0.04213582,
#         -0.5095658 ,  0.07535315, -0.34040058,  0.58199334,  0.02943771,
#         -0.02242354,  0.29460868,  0.50363594,  0.3805013 ,  0.18140475,
#          0.5556229 ,  0.21672045, -0.12970722, -0.07386269,  0.81339455,
#          0.21819647,  0.28317034, -0.4668932 ,  0.11193375,  0.08258843],
#        dtype=float32),
#  array([-0.11650942,  0.37470987,  0.06855327,  0.11697981, -0.10937466,
#         -0.56417227,  0.37688866,  0.9434113 , -0.3677466 , -0.19289134,
#         -0.03579469, -0.29490772,  0.04945434,  0.3897845 ,  0.03221509,
#         -0.25110793,  0.4744101 , -0.6397605 , -0.5029922 , -1.0985618 ,
#          0.2562433 ,  0.15688755,  0.27123973, -0.01097467, -0.02219805,
#          0.07899123, -0.23891088,  0.07265408, -0.2813588 ,  0.2420134 ,
#          0.6438414 , -0.08432961,  0.1629025 , -0.66732454, -0.33915383,
#          0.4156226 ,  0.17767456, -0.43201178, -0.18444653, -0.71991384,
#          0.14420153, -0.40084362, -0.33271188,  0.00389762,  0.18358013,
#         -0.23286617, -0.7137091 , -0.07391365, -0.10199327,  0.13586673,
#          0.29332137, -0.39438936, -0.33202013, -0.0737735 , -0.5861514 ,
#         -0.17302604,  0.22259924, -0.09604528, -0.26866668,  0.2593372 ,
#          0.0762195 , -0.2912362 ,  0.27279043,  0.05028653, -0.51435256,
#          0.5472422 ,  0.3082709 ,  0.4689031 , -0.5439018 ,  0.3845878 ,
#         -0.0591317 ,  0.54765886,  0.26319262, -0.07226936,  0.3579129 ,
#          0.21841648,  0.0860348 ,  0.11809202, -0.5853144 ,  0.15609707,
#         -0.6488636 , -0.16923304, -0.00489914,  0.741895  , -0.26048493,
#         -0.239287  ,  0.33010677,  0.5578099 ,  0.40037233,  0.2982665 ,
#          0.56806624,  0.50240767,  0.1728518 , -0.07691114,  0.953297  ,
#          0.17870331,  0.15984355, -0.44019395,  0.14139861,  0.12961784],
#        dtype=float32),
#  ...]

# %%
X = np.vstack(X) # this converts my 1-dimensional array into a 2-dimensional array which i want for processing
y = df[label_column].values
X

# these are my X and y that i can now use on different things !!
# Out:
# array([[-0.15790641,  0.39799747,  0.15869679, ..., -0.60047442,
#          0.03423499, -0.34574571],
#        [-0.15650554,  0.44710308, -0.00786425, ..., -0.63079149,
#          0.00097574, -0.23692137],
#        [-0.15787987,  0.404971  ,  0.10724876, ..., -0.53993529,
#          0.04716146, -0.12787348],
#        ...,
#        [-0.11679833,  0.31036654, -0.00543177, ..., -0.37155101,
#          0.13076174,  0.1810414 ],
#        [-0.62045902,  0.01210162, -0.10798591, ..., -0.55053878,
#          0.32103887,  0.63439822],
#        [-0.15742815,  0.40616956,  0.06348045, ..., -0.71229476,
#          0.06745058, -0.14255002]], shape=(16990, 100))
